# %%
import pandas as pd

kiva_datasets = ['kiva_loans', 'kiva_mpi_region_locations', 'loan_theme_ids', 'loan_themes_by_region']

kiva_loans_orig = pd.read_csv('kiva-data/' + kiva_datasets[0] + '.csv')
kiva_loans = kiva_loans_orig.copy()
kiva_loans_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null object
# disbursed_time        668809 non-null object
# funded_time           622874 non-null object
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  499789 non-null object
# borrower_genders      666984 non-null object
# repayment_interval    671205 non-null object
# date                  671205 non-null object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 102.4+ MB

# %% [markdown]
# - id: not too useful
# - funded_amount: could be very useful, especially if this can be treated as a label
#     * LABEL?
# - loan_amount: useful to know how much they are asking for
# - activity: could be useful, but there are a lot of categories.
# - sector: only 15 categories, could be very useful
# - use: terrible without any processing, could be used for NLP or parsing out keywords
#     * OPEN ENDED
# - country_code: useful to find country based trends
# - country: basically the same as country_code, can drop 1
# - region: very important for tracking the poverty down to the lowest level possible
# - currency: could be interesting to see correlations between funding time and currency
# - partner_id: not useful on it's own, could be helpful to merge with other datasets that use the same id
#     * USE FOR MERGE
# - posted_time: time based features are useful
#     * CONVERT
#     * LABEL
# - disbursed_time: would be useful to see if people's fudning interests align with disbursal time, however occasionally the loan is disbursed before funding, so this might not be too useful
#     * CONVERT
#     * LABEL?
# - funded_time: useful to determine amount of time between posting and funding
#     * CONVERT
#     * LABEL
# - term_in_months: useful to determine how quickly someone will be able to pay back, which might indicate their poverty level (i.e. 200\$ loan over 12 months indicates higher poverty than 200\$ loan over 6 months)
# - lender_count: more people in the loan might indicate lower or higher welfare need, depending on other features
# - tags: not useful in current state, could use tags as a label in order to predict popular attraction to the loan (separated by ', ')
#     * CONVERT
#     * LABEL?
# - borrower_genders: not useful in current state, could convert to something like num_males, num_females (separated by ', ')
#     * CONVERT
# - repayment_interval: could hold some trends of welfare need
# - date: might be similar/equal to posted_time, might remove
#     * CONVERT

# %%
import time as t

time_cols = ['posted_time', 'disbursed_time', 'funded_time', 'date']

for col in time_cols:
    kiva_loans[col] = pd.to_datetime(kiva_loans_orig[col])

# %%
ary_cols = ['tags', 'borrower_genders']

def to_ar(strg, sep = ', '):
    if strg == 'nan':
        return []
    return strg.split(sep=sep)

for col in ary_cols:
    kiva_loans[col] = kiva_loans_orig[col].astype(str).apply(to_ar)

# %%
kiva_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null datetime64[ns]
# disbursed_time        668809 non-null datetime64[ns]
# funded_time           622874 non-null datetime64[ns]
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  671205 non-null object
# borrower_genders      671205 non-null object
# repayment_interval    671205 non-null object
# date                  671205 non-null datetime64[ns]
# dtypes: datetime64[ns](4), float64(4), int64(2), object(10)
# memory usage: 102.4+ MB

# %%
kiva_loans['time_till_funded'] = (kiva_loans['funded_time'] - kiva_loans['posted_time']).astype('timedelta64[ns]')
kiva_loans['hours_till_funded'] = kiva_loans['time_till_funded'].astype('timedelta64[h]')

# %%
kiva_loans['hours_till_funded'][0]
# Out:
# 27.0

# %%
kiva_loans['hours_till_funded'].describe()
# Out:
# count    622874.000000
# mean        350.896796
# std         345.578870
# min        -421.000000
# 25%         124.000000
# 50%         230.000000
# 75%         540.000000
# max       10093.000000
# Name: hours_till_funded, dtype: float64

# %%
(kiva_loans['hours_till_funded'] < 0).sum()
# Out:
# 1

# %% [markdown]
# For some reason, one of the rows has the funded time before the posted time.

# %%
def ior(i):
    i = iter(i)
    try:
        s = next(i)
    except StopIteration:
        return None
    for e in i:
        s = s | e
    return s

all_tags = ior(kiva_loans['tags'].apply(set))
all_tags
# Out:
# {'#Animals',
#  '#Biz Durable Asset',
#  '#Eco-friendly',
#  '#Elderly',
#  '#Fabrics',
#  '#Female Education',
#  '#First Loan',
#  '#Health and Sanitation',
#  '#Hidden Gem',
#  '#Inspiring Story',
#  '#Interesting Photo',
#  '#Job Creator',
#  '#Low-profit FP',
#  '#Orphan',
#  '#Parent',
#  '#Post-disbursed',
#  '#Refugee',
#  '#Repair Renew Replace',
#  '#Repeat Borrower',
#  '#Schooling',
#  '#Single',
#  '#Single Parent',
#  '#Supporting Family',
#  '#Sustainable Ag',
#  '#Technology',
#  '#Tourism',
#  '#Trees',
#  '#Unique',
#  '#Vegan',
#  '#Widowed',
#  '#Woman Owned Biz',
#  'user_favorite',
#  'user_like',
#  'volunteer_like',
#  'volunteer_pick'}

# %% [markdown]
# Not too many possible tags, could just do a one hot encoding without too many problems.
#
# Here is the one hot encoding for it

# %%
import numpy as np
vecin = np.vectorize(list.__contains__)

for tag in all_tags:
    kiva_loans['tag_' + tag] = vecin(kiva_loans['tags'], tag).astype(int)

kiva_loans['tag_#Trees'].describe()
# Out:
# count    671205.000000
# mean          0.011342
# std           0.105895
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: tag_#Trees, dtype: float64

# %%
kiva_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 57 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector                        671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country                       671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_volunteer_like            671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Animals                  671205 non-null int64
# dtypes: datetime64[ns](4), float64(5), int64(37), object(10), timedelta64[ns](1)
# memory usage: 291.9+ MB

# %%
kiva_loans['num_male_borrowers'] = kiva_loans['borrower_genders'].apply(lambda x: x.count('male'))
kiva_loans['num_female_borrowers'] = kiva_loans['borrower_genders'].apply(len) - kiva_loans['num_male_borrowers']

# %%
(kiva_loans['num_male_borrowers'] > 0).sum()
# Out:
# 178903

# %%
(kiva_loans['num_female_borrowers'] > 0).sum()
# Out:
# 528461

# %% [markdown]
# Interesting to see that the majority of loans have at least 1 female borrower
#
# Below I use the dataset I created using the Google Places API to get a second region which hopefully better matches with the `kiva_mpi_region_locations.csv` dataset

# %%
loan_theme_ids = pd.read_csv('kiva-data/' + kiva_datasets[2] + '.csv')
loan_theme_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779092 entries, 0 to 779091
# Data columns (total 4 columns):
# id                 779092 non-null int64
# Loan Theme ID      764279 non-null object
# Loan Theme Type    764279 non-null object
# Partner ID         764279 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.8+ MB

# %%
kiva_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 59 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector                        671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country                       671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_volunteer_like            671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Animals                  671205 non-null int64
# num_male_borrowers            671205 non-null int64
# num_female_borrowers          671205 non-null int64
# dtypes: datetime64[ns](4), float64(5), int64(39), object(10), timedelta64[ns](1)
# memory usage: 302.1+ MB

# %%
kiva_loan_theme_id = kiva_loans.merge(loan_theme_ids, how='left', on='id')
kiva_loan_theme_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 62 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector                        671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country                       671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_volunteer_like            671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Animals                  671205 non-null int64
# num_male_borrowers            671205 non-null int64
# num_female_borrowers          671205 non-null int64
# Loan Theme ID                 657692 non-null object
# Loan Theme Type               657692 non-null object
# Partner ID                    657692 non-null float64
# dtypes: datetime64[ns](4), float64(6), int64(39), object(12), timedelta64[ns](1)
# memory usage: 322.6+ MB

# %%
loan_theme_region = pd.read_csv('kiva-data/' + kiva_datasets[3] + '.csv')
loan_theme_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15736 entries, 0 to 15735
# Data columns (total 21 columns):
# Partner ID            15736 non-null int64
# Field Partner Name    15736 non-null object
# sector                15736 non-null object
# Loan Theme ID         15736 non-null object
# Loan Theme Type       15736 non-null object
# country               15736 non-null object
# forkiva               15736 non-null object
# region                15736 non-null object
# geocode_old           1200 non-null object
# ISO                   15722 non-null object
# number                15736 non-null int64
# amount                15736 non-null int64
# LocationName          15736 non-null object
# geocode               13662 non-null object
# names                 13661 non-null object
# geo                   15736 non-null object
# lat                   13662 non-null float64
# lon                   13662 non-null float64
# mpi_region            15722 non-null object
# mpi_geo               9671 non-null object
# rural_pct             14344 non-null float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 2.5+ MB

# %%
loan_theme_region.sample(5)
# Out:
#       Partner ID                                 Field Partner Name  \
# 6927         136        Gata Daku Multi-purpose Cooperative (GDMPC)
# 9021         169                                  SEF International
# 1893          81                                     Apoyo Integral
# 580           40  Grounded and Holistic Approach for People's Em...
# 9108         169                                  SEF International
#
#                            sector    Loan Theme ID      Loan Theme Type  \
# 6927  General Financial Inclusion  a1050000000wf0h              General
# 9021  General Financial Inclusion  a1050000006TnqI  Agriculture (Women)
# 1893  General Financial Inclusion  a1050000000SqOh        At-Risk Youth
# 580   General Financial Inclusion  a1050000000shPp      Extreme Poverty
# 9108  General Financial Inclusion  a1050000000daSp        Conflict Zone
#
#           country forkiva                                            region  \
# 6927  Philippines      No  p-7, casusan, oroquieta city, misamis occidental
# 9021      Armenia      No                Mrgastan village, Ejmiatsin region
# 1893  El Salvador      No                                            Gotera
# 580      Cameroon      No                             Nanga Street, Bamenda
# 9108      Armenia     Yes                   Ptghavan village, Tavush region
#
#      geocode_old  ISO    ...     amount  \
# 6927         NaN  PHL    ...        100
# 9021         NaN  ARM    ...       1050
# 1893         NaN  SLV    ...       9050
# 580          NaN  CMR    ...        350
# 9108         NaN  ARM    ...      12775
#
#                                            LocationName  \
# 6927  p-7, casusan, oroquieta city, misamis occident...
# 9021        Mrgastan village, Ejmiatsin region, Armenia
# 1893                                Gotera, El Salvador
# 580                     Nanga Street, Bamenda, Cameroon
# 9108           Ptghavan village, Tavush region, Armenia
#
#                                 geocode  \
# 6927                                NaN
# 9021         [(40.2007545, 44.2770015)]
# 1893        [(13.6927457, -88.1047287)]
# 580                                 NaN
# 9108  [(41.2272725, 44.86106669999999)]
#
#                                                   names  \
# 6927                                                NaN
# 9021                Mrgastan; Armavir Province; Armenia
# 1893  San Francisco Gotera; MorazÍn Department; El ...
# 580                                                 NaN
# 9108                 Ptghavan; Tavush Province; Armenia
#
#                                   geo        lat        lon  \
# 6927                 (1000.0, 1000.0)        NaN        NaN
# 9021         (40.2007545, 44.2770015)  40.200754  44.277002
# 1893        (13.6927457, -88.1047287)  13.692746 -88.104729
# 580                  (1000.0, 1000.0)        NaN        NaN
# 9108  (41.2272725, 44.86106669999999)  41.227272  44.861067
#
#                 mpi_region                 mpi_geo rural_pct
# 6927                   PHL                     NaN      61.0
# 9021                   ARM                     NaN      68.0
# 1893  Morazan, El Salvador  (13.7682, -88.1291387)      57.0
# 580                    CMR                     NaN      93.0
# 9108                   ARM                     NaN      68.0
#
# [5 rows x 21 columns]

# %%
kiva_loans_subregion = kiva_loan_theme_id.merge(loan_theme_region, how='left', on=['Loan Theme ID', 'Partner ID', 'region'])
kiva_loans_subregion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 80 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector_x                      671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country_x                     671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_volunteer_like            671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Animals                  671205 non-null int64
# num_male_borrowers            671205 non-null int64
# num_female_borrowers          671205 non-null int64
# Loan Theme ID                 657692 non-null object
# Loan Theme Type_x             657692 non-null object
# Partner ID                    657692 non-null object
# Field Partner Name            533462 non-null object
# sector_y                      533462 non-null object
# Loan Theme Type_y             533462 non-null object
# country_y                     533462 non-null object
# forkiva                       533462 non-null object
# geocode_old                   108977 non-null object
# ISO                           533461 non-null object
# number                        533462 non-null float64
# amount                        533462 non-null float64
# LocationName                  533462 non-null object
# geocode                       518988 non-null object
# names                         518987 non-null object
# geo                           533462 non-null object
# lat                           518988 non-null float64
# lon                           518988 non-null float64
# mpi_region                    533461 non-null object
# mpi_geo                       459053 non-null object
# rural_pct                     500967 non-null float64
# dtypes: datetime64[ns](4), float64(10), int64(39), object(26), timedelta64[ns](1)
# memory usage: 414.8+ MB

# %%
kiva_loans_subregion_wmpi = kiva_loans_subregion[pd.notnull(kiva_loans_subregion['mpi_region'])]
kiva_loans_subregion_wmpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 533461 entries, 1 to 671149
# Data columns (total 80 columns):
# id                            533461 non-null int64
# funded_amount                 533461 non-null float64
# loan_amount                   533461 non-null float64
# activity                      533461 non-null object
# sector_x                      533461 non-null object
# use                           533456 non-null object
# country_code                  533453 non-null object
# country_x                     533461 non-null object
# region                        533461 non-null object
# currency                      533461 non-null object
# partner_id                    533461 non-null float64
# posted_time                   533461 non-null datetime64[ns]
# disbursed_time                533461 non-null datetime64[ns]
# funded_time                   499549 non-null datetime64[ns]
# term_in_months                533461 non-null float64
# lender_count                  533461 non-null int64
# tags                          533461 non-null object
# borrower_genders              533461 non-null object
# repayment_interval            533461 non-null object
# date                          533461 non-null datetime64[ns]
# time_till_funded              499549 non-null timedelta64[ns]
# hours_till_funded             499549 non-null float64
# tag_volunteer_like            533461 non-null int64
# tag_#Vegan                    533461 non-null int64
# tag_#Unique                   533461 non-null int64
# tag_#Eco-friendly             533461 non-null int64
# tag_#Hidden Gem               533461 non-null int64
# tag_#Biz Durable Asset        533461 non-null int64
# tag_#Woman Owned Biz          533461 non-null int64
# tag_#Schooling                533461 non-null int64
# tag_#Job Creator              533461 non-null int64
# tag_#Health and Sanitation    533461 non-null int64
# tag_#First Loan               533461 non-null int64
# tag_volunteer_pick            533461 non-null int64
# tag_#Refugee                  533461 non-null int64
# tag_user_like                 533461 non-null int64
# tag_#Repeat Borrower          533461 non-null int64
# tag_#Single Parent            533461 non-null int64
# tag_#Orphan                   533461 non-null int64
# tag_#Low-profit FP            533461 non-null int64
# tag_#Widowed                  533461 non-null int64
# tag_user_favorite             533461 non-null int64
# tag_#Tourism                  533461 non-null int64
# tag_#Interesting Photo        533461 non-null int64
# tag_#Post-disbursed           533461 non-null int64
# tag_#Trees                    533461 non-null int64
# tag_#Sustainable Ag           533461 non-null int64
# tag_#Fabrics                  533461 non-null int64
# tag_#Supporting Family        533461 non-null int64
# tag_#Parent                   533461 non-null int64
# tag_#Repair Renew Replace     533461 non-null int64
# tag_#Elderly                  533461 non-null int64
# tag_#Female Education         533461 non-null int64
# tag_#Technology               533461 non-null int64
# tag_#Single                   533461 non-null int64
# tag_#Inspiring Story          533461 non-null int64
# tag_#Animals                  533461 non-null int64
# num_male_borrowers            533461 non-null int64
# num_female_borrowers          533461 non-null int64
# Loan Theme ID                 533461 non-null object
# Loan Theme Type_x             533461 non-null object
# Partner ID                    533461 non-null object
# Field Partner Name            533461 non-null object
# sector_y                      533461 non-null object
# Loan Theme Type_y             533461 non-null object
# country_y                     533461 non-null object
# forkiva                       533461 non-null object
# geocode_old                   108977 non-null object
# ISO                           533461 non-null object
# number                        533461 non-null float64
# amount                        533461 non-null float64
# LocationName                  533461 non-null object
# geocode                       518987 non-null object
# names                         518986 non-null object
# geo                           533461 non-null object
# lat                           518987 non-null float64
# lon                           518987 non-null float64
# mpi_region                    533461 non-null object
# mpi_geo                       459053 non-null object
# rural_pct                     500967 non-null float64
# dtypes: datetime64[ns](4), float64(10), int64(39), object(26), timedelta64[ns](1)
# memory usage: 329.7+ MB

# %%
kiva_mpi_locs = pd.read_csv('kiva-data/' + kiva_datasets[1] + '.csv')
kiva_mpi_locs = kiva_mpi_locs[pd.notnull(kiva_mpi_locs['MPI'])]
kiva_mpi_locs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 1007
# Data columns (total 9 columns):
# LocationName    984 non-null object
# ISO             984 non-null object
# country         984 non-null object
# region          984 non-null object
# world_region    984 non-null object
# MPI             984 non-null float64
# geo             984 non-null object
# lat             892 non-null float64
# lon             892 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 76.9+ KB

# %%
kiva_mpi_locs.sample(5)
# Out:
#                             LocationName  ISO       country  \
# 994                     Northern, Zambia  ZMB        Zambia
# 818                 Bonthe, Sierra Leone  SLE  Sierra Leone
# 328             Huehuetenango, Guatemala  GTM     Guatemala
# 523  El Gharb-Chrarda Bni Hssen, Morocco  MAR       Morocco
# 734                      Sindh, Pakistan  PAK      Pakistan
#
#                          region                 world_region    MPI  \
# 994                    Northern           Sub-Saharan Africa  0.397
# 818                      Bonthe           Sub-Saharan Africa  0.478
# 328               Huehuetenango  Latin America and Caribbean  0.187
# 523  El Gharb-Chrarda Bni Hssen                  Arab States  0.084
# 734                       Sindh                   South Asia  0.294
#
#                                  geo        lat        lon
# 994         (-9.7670177, 30.8958242)  -9.767018  30.895824
# 818           (30.585164, 36.238414)  30.585164  36.238414
# 328        (15.3198766, -91.4918235)  15.319877 -91.491823
# 523           (34.302131, -6.302078)  34.302131  -6.302078
# 734  (25.8943018, 68.52471489999999)  25.894302  68.524715

# %%
kiva_loans_mpi = kiva_loans_subregion_wmpi.merge(kiva_mpi_locs, how='left', left_on='mpi_region', right_on='LocationName')
kiva_loans_mpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 533461 entries, 0 to 533460
# Data columns (total 89 columns):
# id                            533461 non-null int64
# funded_amount                 533461 non-null float64
# loan_amount                   533461 non-null float64
# activity                      533461 non-null object
# sector_x                      533461 non-null object
# use                           533456 non-null object
# country_code                  533453 non-null object
# country_x                     533461 non-null object
# region_x                      533461 non-null object
# currency                      533461 non-null object
# partner_id                    533461 non-null float64
# posted_time                   533461 non-null datetime64[ns]
# disbursed_time                533461 non-null datetime64[ns]
# funded_time                   499549 non-null datetime64[ns]
# term_in_months                533461 non-null float64
# lender_count                  533461 non-null int64
# tags                          533461 non-null object
# borrower_genders              533461 non-null object
# repayment_interval            533461 non-null object
# date                          533461 non-null datetime64[ns]
# time_till_funded              499549 non-null timedelta64[ns]
# hours_till_funded             499549 non-null float64
# tag_volunteer_like            533461 non-null int64
# tag_#Vegan                    533461 non-null int64
# tag_#Unique                   533461 non-null int64
# tag_#Eco-friendly             533461 non-null int64
# tag_#Hidden Gem               533461 non-null int64
# tag_#Biz Durable Asset        533461 non-null int64
# tag_#Woman Owned Biz          533461 non-null int64
# tag_#Schooling                533461 non-null int64
# tag_#Job Creator              533461 non-null int64
# tag_#Health and Sanitation    533461 non-null int64
# tag_#First Loan               533461 non-null int64
# tag_volunteer_pick            533461 non-null int64
# tag_#Refugee                  533461 non-null int64
# tag_user_like                 533461 non-null int64
# tag_#Repeat Borrower          533461 non-null int64
# tag_#Single Parent            533461 non-null int64
# tag_#Orphan                   533461 non-null int64
# tag_#Low-profit FP            533461 non-null int64
# tag_#Widowed                  533461 non-null int64
# tag_user_favorite             533461 non-null int64
# tag_#Tourism                  533461 non-null int64
# tag_#Interesting Photo        533461 non-null int64
# tag_#Post-disbursed           533461 non-null int64
# tag_#Trees                    533461 non-null int64
# tag_#Sustainable Ag           533461 non-null int64
# tag_#Fabrics                  533461 non-null int64
# tag_#Supporting Family        533461 non-null int64
# tag_#Parent                   533461 non-null int64
# tag_#Repair Renew Replace     533461 non-null int64
# tag_#Elderly                  533461 non-null int64
# tag_#Female Education         533461 non-null int64
# tag_#Technology               533461 non-null int64
# tag_#Single                   533461 non-null int64
# tag_#Inspiring Story          533461 non-null int64
# tag_#Animals                  533461 non-null int64
# num_male_borrowers            533461 non-null int64
# num_female_borrowers          533461 non-null int64
# Loan Theme ID                 533461 non-null object
# Loan Theme Type_x             533461 non-null object
# Partner ID                    533461 non-null object
# Field Partner Name            533461 non-null object
# sector_y                      533461 non-null object
# Loan Theme Type_y             533461 non-null object
# country_y                     533461 non-null object
# forkiva                       533461 non-null object
# geocode_old                   108977 non-null object
# ISO_x                         533461 non-null object
# number                        533461 non-null float64
# amount                        533461 non-null float64
# LocationName_x                533461 non-null object
# geocode                       518987 non-null object
# names                         518986 non-null object
# geo_x                         533461 non-null object
# lat_x                         518987 non-null float64
# lon_x                         518987 non-null float64
# mpi_region                    533461 non-null object
# mpi_geo                       459053 non-null object
# rural_pct                     500967 non-null float64
# LocationName_y                458894 non-null object
# ISO_y                         458894 non-null object
# country                       458894 non-null object
# region_y                      458894 non-null object
# world_region                  458894 non-null object
# MPI                           458894 non-null float64
# geo_y                         458894 non-null object
# lat_y                         458894 non-null float64
# lon_y                         458894 non-null float64
# dtypes: datetime64[ns](4), float64(13), int64(39), object(32), timedelta64[ns](1)
# memory usage: 366.3+ MB

# %%
kiva_loans_mpi_final = kiva_loans_mpi[pd.notnull(kiva_loans_mpi['MPI'])]
kiva_loans_mpi_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458894 entries, 0 to 533459
# Data columns (total 89 columns):
# id                            458894 non-null int64
# funded_amount                 458894 non-null float64
# loan_amount                   458894 non-null float64
# activity                      458894 non-null object
# sector_x                      458894 non-null object
# use                           458889 non-null object
# country_code                  458886 non-null object
# country_x                     458894 non-null object
# region_x                      458894 non-null object
# currency                      458894 non-null object
# partner_id                    458894 non-null float64
# posted_time                   458894 non-null datetime64[ns]
# disbursed_time                458894 non-null datetime64[ns]
# funded_time                   431465 non-null datetime64[ns]
# term_in_months                458894 non-null float64
# lender_count                  458894 non-null int64
# tags                          458894 non-null object
# borrower_genders              458894 non-null object
# repayment_interval            458894 non-null object
# date                          458894 non-null datetime64[ns]
# time_till_funded              431465 non-null timedelta64[ns]
# hours_till_funded             431465 non-null float64
# tag_volunteer_like            458894 non-null int64
# tag_#Vegan                    458894 non-null int64
# tag_#Unique                   458894 non-null int64
# tag_#Eco-friendly             458894 non-null int64
# tag_#Hidden Gem               458894 non-null int64
# tag_#Biz Durable Asset        458894 non-null int64
# tag_#Woman Owned Biz          458894 non-null int64
# tag_#Schooling                458894 non-null int64
# tag_#Job Creator              458894 non-null int64
# tag_#Health and Sanitation    458894 non-null int64
# tag_#First Loan               458894 non-null int64
# tag_volunteer_pick            458894 non-null int64
# tag_#Refugee                  458894 non-null int64
# tag_user_like                 458894 non-null int64
# tag_#Repeat Borrower          458894 non-null int64
# tag_#Single Parent            458894 non-null int64
# tag_#Orphan                   458894 non-null int64
# tag_#Low-profit FP            458894 non-null int64
# tag_#Widowed                  458894 non-null int64
# tag_user_favorite             458894 non-null int64
# tag_#Tourism                  458894 non-null int64
# tag_#Interesting Photo        458894 non-null int64
# tag_#Post-disbursed           458894 non-null int64
# tag_#Trees                    458894 non-null int64
# tag_#Sustainable Ag           458894 non-null int64
# tag_#Fabrics                  458894 non-null int64
# tag_#Supporting Family        458894 non-null int64
# tag_#Parent                   458894 non-null int64
# tag_#Repair Renew Replace     458894 non-null int64
# tag_#Elderly                  458894 non-null int64
# tag_#Female Education         458894 non-null int64
# tag_#Technology               458894 non-null int64
# tag_#Single                   458894 non-null int64
# tag_#Inspiring Story          458894 non-null int64
# tag_#Animals                  458894 non-null int64
# num_male_borrowers            458894 non-null int64
# num_female_borrowers          458894 non-null int64
# Loan Theme ID                 458894 non-null object
# Loan Theme Type_x             458894 non-null object
# Partner ID                    458894 non-null object
# Field Partner Name            458894 non-null object
# sector_y                      458894 non-null object
# Loan Theme Type_y             458894 non-null object
# country_y                     458894 non-null object
# forkiva                       458894 non-null object
# geocode_old                   95871 non-null object
# ISO_x                         458894 non-null object
# number                        458894 non-null float64
# amount                        458894 non-null float64
# LocationName_x                458894 non-null object
# geocode                       458894 non-null object
# names                         458894 non-null object
# geo_x                         458894 non-null object
# lat_x                         458894 non-null float64
# lon_x                         458894 non-null float64
# mpi_region                    458894 non-null object
# mpi_geo                       458894 non-null object
# rural_pct                     436443 non-null float64
# LocationName_y                458894 non-null object
# ISO_y                         458894 non-null object
# country                       458894 non-null object
# region_y                      458894 non-null object
# world_region                  458894 non-null object
# MPI                           458894 non-null float64
# geo_y                         458894 non-null object
# lat_y                         458894 non-null float64
# lon_y                         458894 non-null float64
# dtypes: datetime64[ns](4), float64(13), int64(39), object(32), timedelta64[ns](1)
# memory usage: 315.1+ MB

# %%
kiva_loans_mpi_final[~pd.notnull(kiva_loans_mpi_final['funded_time'])]
# Out:
#              id  funded_amount  loan_amount                   activity  \
# 486      653916          475.0       1050.0                        Pub
# 495      653912          500.0       1050.0                  Beverages
# 591      654153          975.0       1475.0           Wedding Expenses
# 663      653957         1725.0       2600.0                Agriculture
# 690      654104          550.0       1050.0           Wedding Expenses
# 700      654005          825.0       1550.0                Agriculture
# 755      654478          750.0        925.0       Motorcycle Transport
# 756      654582         3300.0       5525.0             Clothing Sales
# 786      654721          550.0        925.0       Motorcycle Transport
# 794      654630          875.0       1500.0           Wedding Expenses
# 828      654574          650.0       1050.0           Wedding Expenses
# 843      654471          800.0       1050.0       Motorcycle Transport
# 849      654541          575.0       1000.0             Consumer Goods
# 882      654660          375.0        950.0               Animal Sales
# 914      654869          125.0       1550.0              Mobile Phones
# 938      654548          425.0        850.0           Wedding Expenses
# 991      654484          775.0       1025.0       Motorcycle Transport
# 997      654778          700.0       1000.0             Clothing Sales
# 1027     655309         2350.0       3625.0                     Retail
# 1089     655067          750.0       1575.0           Wedding Expenses
# 1105     654951         1625.0       2000.0                Agriculture
# 1110     655099         1300.0       1575.0           Wedding Expenses
# 1120     655139         1050.0       2000.0                Agriculture
# 1185     655367          450.0        800.0                     Retail
# 1255     655117          750.0       2000.0               Animal Sales
# 1274     655357         1925.0       3775.0      Food Production/Sales
# 1563     655607         1450.0       1575.0  Personal Housing Expenses
# 1641     655501          425.0       1050.0                Food Market
# 1797     656094          450.0       1000.0           Wedding Expenses
# 1912     656295         1200.0       2000.0               Animal Sales
# ...         ...            ...          ...                        ...
# 533405  1338605            0.0        300.0        Fruits & Vegetables
# 533407  1338627            0.0        400.0             Clothing Sales
# 533408  1338402            0.0       1000.0                     Cattle
# 533410  1338465           75.0        500.0                    Farming
# 533411  1338416           75.0        450.0                Agriculture
# 533412  1338601            0.0        325.0      Food Production/Sales
# 533414  1338352          150.0        600.0                    Farming
# 533415  1337875           50.0       1925.0         Education provider
# 533416  1338385           50.0       1500.0                      Dairy
# 533417  1338393           50.0       4925.0                Auto Repair
# 533418  1338558            0.0        150.0                  Beverages
# 533419  1338384           50.0        700.0                  Livestock
# 533423  1338874           50.0        350.0                     Sewing
# 533425  1339254            0.0       1300.0                    Farming
# 533426  1339237            0.0       1300.0                       Pigs
# 533427  1339195          100.0       1150.0            Office Supplies
# 533432  1339202            0.0        575.0                     Sewing
# 533435  1339110            0.0        250.0  Personal Medical Expenses
# 533436  1339182           50.0        475.0               Animal Sales
# 533439  1339244           75.0       1000.0                    Farming
# 533441  1338859            0.0        575.0                Food Market
# 533442  1339091           75.0        350.0                  Livestock
# 533443  1338844            0.0       3425.0  Personal Medical Expenses
# 533446  1339073            0.0        925.0                     Sewing
# 533448  1339831           50.0       1150.0     Higher education costs
# 533449  1339925           75.0        575.0               Animal Sales
# 533453  1339765            0.0        925.0                     Sewing
# 533457  1339916            0.0        700.0                  Livestock
# 533458  1339743            0.0        250.0                 Food Stall
# 533459  1339874            0.0        400.0  Personal Medical Expenses
#
#               sector_x                                                use  \
# 486               Food                             to buy stock wholesale
# 495               Food  buy a motorcycle along with cargo and packaged...
# 591       Personal Use              to put on a wedding party for her son
# 663        Agriculture  to buy wholesale farming supplies (seeds, manu...
# 690       Personal Use           pay for her daughter's wedding reception
# 700        Agriculture  To purchase inventory wholesale (snacks, soft ...
# 755     Transportation        to repair and service his three motocycles
# 756           Clothing                          to buy clothes to resell.
# 786     Transportation  to purchase spare parts for his motorbike and ...
# 794       Personal Use                      to hold a wedding for his son
# 828       Personal Use                   To pay for her sister's wedding.
# 843     Transportation                    to purchase another motorcycle.
# 849       Personal Use                to buy furniture for her household
# 882        Agriculture                To buy cattle for his new business.
# 914             Retail                                to stock his store.
# 938       Personal Use                to hold a wedding party for her son
# 991     Transportation                           to purchase a motorcycle
# 997           Clothing                                   to buy clothing.
# 1027            Retail  to buy men's and women's trousers, shirts, blo...
# 1089      Personal Use  To hold a wedding party for her daughter, and ...
# 1105       Agriculture                                purchase fertilizer
# 1110      Personal Use  To hold a wedding party for her daughter and p...
# 1120       Agriculture                                     purchase seeds
# 1185            Retail  to buy towels, bed linens, fruit dishes, rice,...
# 1255       Agriculture  to buy livestock and start his animal husbandr...
# 1274              Food  to purchase chicken, oil, flour, plantains, ch...
# 1563           Housing     to buy building materials to repair her house.
# 1641              Food  To open a grocery store and purchase the first...
# 1797      Personal Use             To make her daughter’s marriage party
# 1912       Agriculture        to buy livestock and start his own business
# ...                ...                                                ...
# 533405            Food  to purchase a cart to sell fruit and she will ...
# 533407        Clothing  to buy women's clothing such as blouses, pants...
# 533408     Agriculture                    Translated loan use to english.
# 533410     Agriculture                            to purchase fertilizer.
# 533411     Agriculture  Rosa to buy agricultural inputs to grow basic ...
# 533412            Food  to purchase a new industrial griddle to sell t...
# 533414     Agriculture                                 to buy fungicides.
# 533415       Education  to continue and complete studies in Industrial...
# 533416     Agriculture                                to buy a dairy cow.
# 533417        Services                     to buy tools for his services.
# 533418            Food      to buy cases of beer for the deli he manages.
# 533419     Agriculture                         to buy livestock to raise.
# 533423        Services  to purchase quality fabrics to satisfy her cus...
# 533425     Agriculture  to buy compost and fertilizers and to hire wor...
# 533426     Agriculture          to buy pigs, potatoes, and balanced feed.
# 533427          Retail  to purchase office supplies to open a store an...
# 533432        Services  to purchase quality fabric and to pay for her ...
# 533435          Health                  for his wife's medical treatment.
# 533436     Agriculture      to purchase livestock to start a new business
# 533439     Agriculture            to buy fertilizer and contract workers.
# 533441            Food  to purchase food products and start a new busi...
# 533442     Agriculture  to buy livestock to start a new business and p...
# 533443          Health  to purchase medications and pay for her medica...
# 533446        Services  to purchase a modernized sewing machine and ot...
# 533448       Education  to pay his nephews' tuition, so that they can ...
# 533449     Agriculture          to purchase cattle to expand her business
# 533453        Services  to purchase sewing supplies to expand her busi...
# 533457     Agriculture    to purchase livestock and expand her activities
# 533458            Food         to buy watermelon to start a new business.
# 533459          Health   to pay for her son's immediate medical treatment
#
#        country_code    country_x               region_x currency    ...      \
# 486              CO     Colombia                  Andes      COP    ...
# 495              CO     Colombia              La Dorada      COP    ...
# 591              TJ   Tajikistan                  Yavan      TJS    ...
# 663              CO     Colombia   El Carmen de Viboral      COP    ...
# 690              TJ   Tajikistan                 Isfara      TJS    ...
# 700              CO     Colombia                 Sonson      COP    ...
# 755              KE        Kenya                  Narok      KES    ...
# 756              TZ     Tanzania          Dar es Salaam      TZS    ...
# 786              KE        Kenya                Samburu      KES    ...
# 794              TJ   Tajikistan              Panjakent      USD    ...
# 828              TJ   Tajikistan              Panjakent      TJS    ...
# 843              KE        Kenya                  Narok      KES    ...
# 849              TJ   Tajikistan              Panjakent      USD    ...
# 882              TJ   Tajikistan                 Gissar      TJS    ...
# 914              CO     Colombia  Santa Fe de Antioquia      COP    ...
# 938              TJ   Tajikistan              Panjakent      TJS    ...
# 991              KE        Kenya                  Narok      KES    ...
# 997              HN     Honduras            San Lorenzo      HNL    ...
# 1027             NI    Nicaragua                 Masaya      NIO    ...
# 1089             TJ   Tajikistan               Dushanbe      TJS    ...
# 1105             TJ   Tajikistan            Istaravshan      USD    ...
# 1110             TJ   Tajikistan            Istaravshan      TJS    ...
# 1120             TJ   Tajikistan            Istaravshan      USD    ...
# 1185             NI    Nicaragua                 Masaya      NIO    ...
# 1255             TJ   Tajikistan                Farkhor      USD    ...
# 1274             NI    Nicaragua                 Masaya      NIO    ...
# 1563             TJ   Tajikistan              Kanibadam      TJS    ...
# 1641             TJ   Tajikistan              Konibodom      TJS    ...
# 1797             TJ   Tajikistan                  Yavan      USD    ...
# 1912             TJ   Tajikistan                  Yavan      USD    ...
# ...             ...          ...                    ...      ...    ...
# 533405           SV  El Salvador                 Gotera      USD    ...
# 533407           CO     Colombia              Marinilla      COP    ...
# 533408           EC      Ecuador            San Gabriel      USD    ...
# 533410           EC      Ecuador            San Gabriel      USD    ...
# 533411           SV  El Salvador             San Miguel      USD    ...
# 533412           SV  El Salvador                 Gotera      USD    ...
# 533414           EC      Ecuador            San Gabriel      USD    ...
# 533415           PE         Peru                   Lima      USD    ...
# 533416           EC      Ecuador            San Gabriel      USD    ...
# 533417           BO      Bolivia             Monteagudo      BOB    ...
# 533418           CO     Colombia                Sampues      COP    ...
# 533419           CO     Colombia   El Carmen de Bolivar      COP    ...
# 533423           TJ   Tajikistan               Khuroson      TJS    ...
# 533425           EC      Ecuador            San Gabriel      USD    ...
# 533426           EC      Ecuador            San Gabriel      USD    ...
# 533427           TJ   Tajikistan               Khuroson      TJS    ...
# 533432           TJ   Tajikistan               Khuroson      TJS    ...
# 533435           TJ   Tajikistan                 Rudaki      TJS    ...
# 533436           TJ   Tajikistan                  Yavan      TJS    ...
# 533439           EC      Ecuador            San Gabriel      USD    ...
# 533441           TJ   Tajikistan                A. Jomi      TJS    ...
# 533442           TJ   Tajikistan                 Vahdat      TJS    ...
# 533443           TJ   Tajikistan                 Isfara      TJS    ...
# 533446           TJ   Tajikistan                 Vahdat      TJS    ...
# 533448           TJ   Tajikistan            Qurgan-Tube      TJS    ...
# 533449           TJ   Tajikistan               Khuroson      TJS    ...
# 533453           TJ   Tajikistan               Dushanbe      TJS    ...
# 533457           TJ   Tajikistan               Khuroson      TJS    ...
# 533458           TJ   Tajikistan               Spitamen      TJS    ...
# 533459           TJ   Tajikistan                 Isfara      TJS    ...
#
#         rural_pct                                     LocationName_y ISO_y  \
# 486          16.0                            Medellin A.M., Colombia   COL
# 495          16.0                            Medellin A.M., Colombia   COL
# 591           0.0                               Dushanbe, Tajikistan   TJK
# 663          16.0                            Medellin A.M., Colombia   COL
# 690           0.0  Districts of Republican Subordination, Tajikistan   TJK
# 700          16.0                            Medellin A.M., Colombia   COL
# 755          65.0                                     Nairobi, Kenya   KEN
# 756           0.0             Zanzibar, Tanzania, United Republic of   TZA
# 786          99.0                               North Eastern, Kenya   KEN
# 794           0.0                               Dushanbe, Tajikistan   TJK
# 828           0.0                               Dushanbe, Tajikistan   TJK
# 843          65.0                                     Nairobi, Kenya   KEN
# 849           0.0                               Dushanbe, Tajikistan   TJK
# 882           0.0                               Dushanbe, Tajikistan   TJK
# 914          16.0                            Medellin A.M., Colombia   COL
# 938           0.0                               Dushanbe, Tajikistan   TJK
# 991          65.0                                     Nairobi, Kenya   KEN
# 997          90.0                                    Valle, Honduras   HND
# 1027         40.0                                  Masaya, Nicaragua   NIC
# 1089          0.0                               Dushanbe, Tajikistan   TJK
# 1105         62.0                                  Sughd, Tajikistan   TJK
# 1110          0.0                                  Sughd, Tajikistan   TJK
# 1120         62.0                                  Sughd, Tajikistan   TJK
# 1185         40.0                                  Masaya, Nicaragua   NIC
# 1255         80.0                                Khatlon, Tajikistan   TJK
# 1274         40.0                                  Masaya, Nicaragua   NIC
# 1563          0.0  Districts of Republican Subordination, Tajikistan   TJK
# 1641         80.0  Districts of Republican Subordination, Tajikistan   TJK
# 1797          0.0                               Dushanbe, Tajikistan   TJK
# 1912         80.0                               Dushanbe, Tajikistan   TJK
# ...           ...                                                ...   ...
# 533405       87.0                               Morazan, El Salvador   SLV
# 533407       16.0                            Medellin A.M., Colombia   COL
# 533408       49.0                          Galapagos Island, Ecuador   ECU
# 533410       49.0                          Galapagos Island, Ecuador   ECU
# 533411       87.0                            San Miguel, El Salvador   SLV
# 533412       87.0                               Morazan, El Salvador   SLV
# 533414       49.0                          Galapagos Island, Ecuador   ECU
# 533415       99.0                                         Lima, Peru   PER
# 533416       49.0                          Galapagos Island, Ecuador   ECU
# 533417       70.0        Chuquisaca, Bolivia, Plurinational State of   BOL
# 533418       16.0                       Barranquilla A. M., Colombia   COL
# 533419       16.0                       Barranquilla A. M., Colombia   COL
# 533423       80.0                               Dushanbe, Tajikistan   TJK
# 533425       49.0                          Galapagos Island, Ecuador   ECU
# 533426       49.0                          Galapagos Island, Ecuador   ECU
# 533427       80.0                               Dushanbe, Tajikistan   TJK
# 533432       80.0                               Dushanbe, Tajikistan   TJK
# 533435       80.0                               Dushanbe, Tajikistan   TJK
# 533436       80.0                               Dushanbe, Tajikistan   TJK
# 533439       49.0                          Galapagos Island, Ecuador   ECU
# 533441       80.0                                Khatlon, Tajikistan   TJK
# 533442       80.0                               Dushanbe, Tajikistan   TJK
# 533443       80.0  Districts of Republican Subordination, Tajikistan   TJK
# 533446       80.0                               Dushanbe, Tajikistan   TJK
# 533448       80.0                                Khatlon, Tajikistan   TJK
# 533449       80.0                               Dushanbe, Tajikistan   TJK
# 533453       80.0                               Dushanbe, Tajikistan   TJK
# 533457       80.0                               Dushanbe, Tajikistan   TJK
# 533458       80.0                                  Sughd, Tajikistan   TJK
# 533459       80.0  Districts of Republican Subordination, Tajikistan   TJK
#
#                                 country  \
# 486                            Colombia
# 495                            Colombia
# 591                          Tajikistan
# 663                            Colombia
# 690                          Tajikistan
# 700                            Colombia
# 755                               Kenya
# 756        Tanzania, United Republic of
# 786                               Kenya
# 794                          Tajikistan
# 828                          Tajikistan
# 843                               Kenya
# 849                          Tajikistan
# 882                          Tajikistan
# 914                            Colombia
# 938                          Tajikistan
# 991                               Kenya
# 997                            Honduras
# 1027                          Nicaragua
# 1089                         Tajikistan
# 1105                         Tajikistan
# 1110                         Tajikistan
# 1120                         Tajikistan
# 1185                          Nicaragua
# 1255                         Tajikistan
# 1274                          Nicaragua
# 1563                         Tajikistan
# 1641                         Tajikistan
# 1797                         Tajikistan
# 1912                         Tajikistan
# ...                                 ...
# 533405                      El Salvador
# 533407                         Colombia
# 533408                          Ecuador
# 533410                          Ecuador
# 533411                      El Salvador
# 533412                      El Salvador
# 533414                          Ecuador
# 533415                             Peru
# 533416                          Ecuador
# 533417  Bolivia, Plurinational State of
# 533418                         Colombia
# 533419                         Colombia
# 533423                       Tajikistan
# 533425                          Ecuador
# 533426                          Ecuador
# 533427                       Tajikistan
# 533432                       Tajikistan
# 533435                       Tajikistan
# 533436                       Tajikistan
# 533439                          Ecuador
# 533441                       Tajikistan
# 533442                       Tajikistan
# 533443                       Tajikistan
# 533446                       Tajikistan
# 533448                       Tajikistan
# 533449                       Tajikistan
# 533453                       Tajikistan
# 533457                       Tajikistan
# 533458                       Tajikistan
# 533459                       Tajikistan
#
#                                      region_y                 world_region  \
# 486                             Medellin A.M.  Latin America and Caribbean
# 495                             Medellin A.M.  Latin America and Caribbean
# 591                                  Dushanbe      Europe and Central Asia
# 663                             Medellin A.M.  Latin America and Caribbean
# 690     Districts of Republican Subordination      Europe and Central Asia
# 700                             Medellin A.M.  Latin America and Caribbean
# 755                                   Nairobi           Sub-Saharan Africa
# 756                                  Zanzibar           Sub-Saharan Africa
# 786                             North Eastern           Sub-Saharan Africa
# 794                                  Dushanbe      Europe and Central Asia
# 828                                  Dushanbe      Europe and Central Asia
# 843                                   Nairobi           Sub-Saharan Africa
# 849                                  Dushanbe      Europe and Central Asia
# 882                                  Dushanbe      Europe and Central Asia
# 914                             Medellin A.M.  Latin America and Caribbean
# 938                                  Dushanbe      Europe and Central Asia
# 991                                   Nairobi           Sub-Saharan Africa
# 997                                     Valle  Latin America and Caribbean
# 1027                                   Masaya  Latin America and Caribbean
# 1089                                 Dushanbe      Europe and Central Asia
# 1105                                    Sughd      Europe and Central Asia
# 1110                                    Sughd      Europe and Central Asia
# 1120                                    Sughd      Europe and Central Asia
# 1185                                   Masaya  Latin America and Caribbean
# 1255                                  Khatlon      Europe and Central Asia
# 1274                                   Masaya  Latin America and Caribbean
# 1563    Districts of Republican Subordination      Europe and Central Asia
# 1641    Districts of Republican Subordination      Europe and Central Asia
# 1797                                 Dushanbe      Europe and Central Asia
# 1912                                 Dushanbe      Europe and Central Asia
# ...                                       ...                          ...
# 533405                                Morazan  Latin America and Caribbean
# 533407                          Medellin A.M.  Latin America and Caribbean
# 533408                       Galapagos Island  Latin America and Caribbean
# 533410                       Galapagos Island  Latin America and Caribbean
# 533411                             San Miguel  Latin America and Caribbean
# 533412                                Morazan  Latin America and Caribbean
# 533414                       Galapagos Island  Latin America and Caribbean
# 533415                                   Lima  Latin America and Caribbean
# 533416                       Galapagos Island  Latin America and Caribbean
# 533417                             Chuquisaca  Latin America and Caribbean
# 533418                     Barranquilla A. M.  Latin America and Caribbean
# 533419                     Barranquilla A. M.  Latin America and Caribbean
# 533423                               Dushanbe      Europe and Central Asia
# 533425                       Galapagos Island  Latin America and Caribbean
# 533426                       Galapagos Island  Latin America and Caribbean
# 533427                               Dushanbe      Europe and Central Asia
# 533432                               Dushanbe      Europe and Central Asia
# 533435                               Dushanbe      Europe and Central Asia
# 533436                               Dushanbe      Europe and Central Asia
# 533439                       Galapagos Island  Latin America and Caribbean
# 533441                                Khatlon      Europe and Central Asia
# 533442                               Dushanbe      Europe and Central Asia
# 533443  Districts of Republican Subordination      Europe and Central Asia
# 533446                               Dushanbe      Europe and Central Asia
# 533448                                Khatlon      Europe and Central Asia
# 533449                               Dushanbe      Europe and Central Asia
# 533453                               Dushanbe      Europe and Central Asia
# 533457                               Dushanbe      Europe and Central Asia
# 533458                                  Sughd      Europe and Central Asia
# 533459  Districts of Republican Subordination      Europe and Central Asia
#
#           MPI                             geo_y      lat_y      lon_y
# 486     0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 495     0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 591     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 663     0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 690     0.045          (39.0857902, 70.2408325)  39.085790  70.240832
# 700     0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 755     0.020          (-1.2920659, 36.8219462)  -1.292066  36.821946
# 756     0.143  (-6.135729500000001, 39.3621196)  -6.135730  39.362120
# 786     0.509          (-0.0190061, 37.6480812)  -0.019006  37.648081
# 794     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 828     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 843     0.020          (-1.2920659, 36.8219462)  -1.292066  36.821946
# 849     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 882     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 914     0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 938     0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 991     0.020          (-1.2920659, 36.8219462)  -1.292066  36.821946
# 997     0.068         (13.5782936, -87.5791287)  13.578294 -87.579129
# 1027    0.017         (11.9704485, -86.0886366)  11.970448 -86.088637
# 1089    0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 1105    0.033           (39.5155326, 69.097023)  39.515533  69.097023
# 1110    0.033           (39.5155326, 69.097023)  39.515533  69.097023
# 1120    0.033           (39.5155326, 69.097023)  39.515533  69.097023
# 1185    0.017         (11.9704485, -86.0886366)  11.970448 -86.088637
# 1255    0.086           (37.9113562, 69.097023)  37.911356  69.097023
# 1274    0.017         (11.9704485, -86.0886366)  11.970448 -86.088637
# 1563    0.045          (39.0857902, 70.2408325)  39.085790  70.240832
# 1641    0.045          (39.0857902, 70.2408325)  39.085790  70.240832
# 1797    0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 1912    0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# ...       ...                               ...        ...        ...
# 533405  0.040            (13.7682, -88.1291387)  13.768200 -88.129139
# 533407  0.005           (6.244203, -75.5812119)   6.244203 -75.581212
# 533408  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533410  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533411  0.030         (13.4792922, -88.1779182)  13.479292 -88.177918
# 533412  0.040            (13.7682, -88.1291387)  13.768200 -88.129139
# 533414  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533415  0.004         (-12.0463731, -77.042754) -12.046373 -77.042754
# 533416  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533417  0.145        (-20.0249144, -64.1478236) -20.024914 -64.147824
# 533418  0.009  (11.0041072, -74.80698129999999)  11.004107 -74.806981
# 533419  0.009  (11.0041072, -74.80698129999999)  11.004107 -74.806981
# 533423  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533425  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533426  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533427  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533432  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533435  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533436  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533439  0.003         (-0.2051725, -78.4896935)  -0.205172 -78.489694
# 533441  0.086           (37.9113562, 69.097023)  37.911356  69.097023
# 533442  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533443  0.045          (39.0857902, 70.2408325)  39.085790  70.240832
# 533446  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533448  0.086           (37.9113562, 69.097023)  37.911356  69.097023
# 533449  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533453  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533457  0.021          (38.5597722, 68.7870384)  38.559772  68.787038
# 533458  0.033           (39.5155326, 69.097023)  39.515533  69.097023
# 533459  0.045          (39.0857902, 70.2408325)  39.085790  70.240832
#
# [27429 rows x 89 columns]

# %%
subnat_regions = pd.read_csv('subnat_regions.csv').drop('id', axis=1)

# %%
subnat_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12821 entries, 0 to 12820
# Data columns (total 3 columns):
# region           12749 non-null object
# country          12821 non-null object
# subnat_region    12733 non-null object
# dtypes: object(3)
# memory usage: 300.6+ KB

# %%
kiva_subnat_loans = kiva_loans.merge(subnat_regions, how='left', on=['region', 'country'])

# %%
kiva_subnat_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 60 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector                        671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country                       671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_volunteer_like            671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Animals                  671205 non-null int64
# num_male_borrowers            671205 non-null int64
# num_female_borrowers          671205 non-null int64
# subnat_region                 614184 non-null object
# dtypes: datetime64[ns](4), float64(5), int64(39), object(11), timedelta64[ns](1)
# memory usage: 312.4+ MB

# %%
kiva_mpi_region_locations_orig = pd.read_csv('kiva-data/' + kiva_datasets[1] + '.csv')
mpi_nat_orig = pd.read_csv('mpi-data/MPI_national.csv')
mpi_subnat_orig = pd.read_csv('mpi-data/MPI_subnational.csv')
kiva_mpi_region_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 9 columns):
# LocationName    984 non-null object
# ISO             1008 non-null object
# country         1008 non-null object
# region          984 non-null object
# world_region    1008 non-null object
# MPI             984 non-null float64
# geo             2772 non-null object
# lat             892 non-null float64
# lon             892 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 195.0+ KB

# %%
kiva_mpi_region_locations = kiva_mpi_region_locations_orig.rename(lambda x: 'mr_' + str(x), axis=1)
mpi_nat = mpi_nat_orig.rename(lambda x: 'mn_' + str(x), axis=1)
mpi_subnat = mpi_subnat_orig.rename(lambda x: 'ms_' + str(x), axis=1)

# %%
kiva_mpi_region_locations = kiva_mpi_region_locations[pd.notnull(kiva_mpi_region_locations['mr_MPI'])]
kiva_mpi_region_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 1007
# Data columns (total 9 columns):
# mr_LocationName    984 non-null object
# mr_ISO             984 non-null object
# mr_country         984 non-null object
# mr_region          984 non-null object
# mr_world_region    984 non-null object
# mr_MPI             984 non-null float64
# mr_geo             984 non-null object
# mr_lat             892 non-null float64
# mr_lon             892 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 76.9+ KB

# %%
mpi_subnat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 8 columns):
# ms_ISO country code                     984 non-null object
# ms_Country                              984 non-null object
# ms_Sub-national region                  984 non-null object
# ms_World region                         984 non-null object
# ms_MPI National                         984 non-null float64
# ms_MPI Regional                         984 non-null float64
# ms_Headcount Ratio Regional             984 non-null float64
# ms_Intensity of deprivation Regional    983 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 61.6+ KB

# %%
subnat_info = kiva_mpi_region_locations.merge(mpi_subnat, how='outer', left_on=['mr_country', 'mr_region', 'mr_world_region'], right_on=['ms_Country', 'ms_Sub-national region', 'ms_World region'])

# %%
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 17 columns):
# mr_LocationName                         984 non-null object
# mr_ISO                                  984 non-null object
# mr_country                              984 non-null object
# mr_region                               984 non-null object
# mr_world_region                         984 non-null object
# mr_MPI                                  984 non-null float64
# mr_geo                                  984 non-null object
# mr_lat                                  892 non-null float64
# mr_lon                                  892 non-null float64
# ms_ISO country code                     984 non-null object
# ms_Country                              984 non-null object
# ms_Sub-national region                  984 non-null object
# ms_World region                         984 non-null object
# ms_MPI National                         984 non-null float64
# ms_MPI Regional                         984 non-null float64
# ms_Headcount Ratio Regional             984 non-null float64
# ms_Intensity of deprivation Regional    983 non-null float64
# dtypes: float64(7), object(10)
# memory usage: 138.4+ KB

# %% [markdown]
# Did outer join in order to add any columns that were in one but not the other, so can remove/rename the country, region and world region features that are duplicated, because they have to match. If statements just prevents errors from repeated runs

# %%
rem = ['mr_country','mr_region','mr_world_region','ms_Country','ms_Sub-national region','ms_World region']
if set(rem).issubset(subnat_info.keys()):
    subnat_info['country'] = subnat_info['mr_country']
    subnat_info['region'] = subnat_info['mr_region']
    subnat_info['world_region'] = subnat_info['mr_world_region']
    subnat_info.drop(rem, axis=1, inplace=True)

# %%
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 14 columns):
# mr_LocationName                         984 non-null object
# mr_ISO                                  984 non-null object
# mr_MPI                                  984 non-null float64
# mr_geo                                  984 non-null object
# mr_lat                                  892 non-null float64
# mr_lon                                  892 non-null float64
# ms_ISO country code                     984 non-null object
# ms_MPI National                         984 non-null float64
# ms_MPI Regional                         984 non-null float64
# ms_Headcount Ratio Regional             984 non-null float64
# ms_Intensity of deprivation Regional    983 non-null float64
# country                                 984 non-null object
# region                                  984 non-null object
# world_region                            984 non-null object
# dtypes: float64(7), object(7)
# memory usage: 115.3+ KB

# %%
(subnat_info['mr_ISO'] != subnat_info['ms_ISO country code']).sum()
# Out:
# 0

# %% [markdown]
# Features are identical, so remove one, rename the other

# %%
rem = ['ms_ISO country code', 'mr_ISO']
if set(rem).issubset(subnat_info.keys()):
    subnat_info['ISO'] = subnat_info['mr_ISO']
    subnat_info.drop(rem, axis=1, inplace=True)

# %%
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 13 columns):
# mr_LocationName                         984 non-null object
# mr_MPI                                  984 non-null float64
# mr_geo                                  984 non-null object
# mr_lat                                  892 non-null float64
# mr_lon                                  892 non-null float64
# ms_MPI National                         984 non-null float64
# ms_MPI Regional                         984 non-null float64
# ms_Headcount Ratio Regional             984 non-null float64
# ms_Intensity of deprivation Regional    983 non-null float64
# country                                 984 non-null object
# region                                  984 non-null object
# world_region                            984 non-null object
# ISO                                     984 non-null object
# dtypes: float64(7), object(6)
# memory usage: 107.6+ KB

# %%
(subnat_info['mr_MPI'] != subnat_info['ms_MPI Regional']).sum()
# Out:
# 0

# %% [markdown]
# Features identical, remove/rename them

# %%
rem = ['mr_MPI', 'ms_MPI Regional']
if set(rem).issubset(subnat_info.keys()):
    subnat_info['mpi_regional'] = subnat_info['mr_MPI']
    subnat_info.drop(rem, axis=1, inplace=True)

# %%
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 12 columns):
# mr_LocationName                         984 non-null object
# mr_geo                                  984 non-null object
# mr_lat                                  892 non-null float64
# mr_lon                                  892 non-null float64
# ms_MPI National                         984 non-null float64
# ms_Headcount Ratio Regional             984 non-null float64
# ms_Intensity of deprivation Regional    983 non-null float64
# country                                 984 non-null object
# region                                  984 non-null object
# world_region                            984 non-null object
# ISO                                     984 non-null object
# mpi_regional                            984 non-null float64
# dtypes: float64(6), object(6)
# memory usage: 99.9+ KB

# %% [markdown]
# Rest of the features are unique, so I will rename them to something a little better

# %%
import re
rn_lam = lambda colname: colname[3:].lower().replace(' ', '_') if re.match('m._.*', colname) is not None else colname
subnat_info.rename(rn_lam, axis=1, inplace=True)
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 12 columns):
# locationname                         984 non-null object
# geo                                  984 non-null object
# lat                                  892 non-null float64
# lon                                  892 non-null float64
# mpi_national                         984 non-null float64
# headcount_ratio_regional             984 non-null float64
# intensity_of_deprivation_regional    983 non-null float64
# country                              984 non-null object
# region                               984 non-null object
# world_region                         984 non-null object
# ISO                                  984 non-null object
# mpi_regional                         984 non-null float64
# dtypes: float64(6), object(6)
# memory usage: 99.9+ KB

# %%
mpi_nat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# mn_ISO                               102 non-null object
# mn_Country                           102 non-null object
# mn_MPI Urban                         102 non-null float64
# mn_Headcount Ratio Urban             102 non-null float64
# mn_Intensity of Deprivation Urban    102 non-null float64
# mn_MPI Rural                         102 non-null float64
# mn_Headcount Ratio Rural             102 non-null float64
# mn_Intensity of Deprivation Rural    102 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 6.5+ KB

# %%
subnat_info = subnat_info.merge(mpi_nat, how='left', left_on=['country', 'ISO'], right_on=['mn_Country', 'mn_ISO'])
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 20 columns):
# locationname                         984 non-null object
# geo                                  984 non-null object
# lat                                  892 non-null float64
# lon                                  892 non-null float64
# mpi_national                         984 non-null float64
# headcount_ratio_regional             984 non-null float64
# intensity_of_deprivation_regional    983 non-null float64
# country                              984 non-null object
# region                               984 non-null object
# world_region                         984 non-null object
# ISO                                  984 non-null object
# mpi_regional                         984 non-null float64
# mn_ISO                               984 non-null object
# mn_Country                           984 non-null object
# mn_MPI Urban                         984 non-null float64
# mn_Headcount Ratio Urban             984 non-null float64
# mn_Intensity of Deprivation Urban    984 non-null float64
# mn_MPI Rural                         984 non-null float64
# mn_Headcount Ratio Rural             984 non-null float64
# mn_Intensity of Deprivation Rural    984 non-null float64
# dtypes: float64(12), object(8)
# memory usage: 161.4+ KB

# %%
subnat_info.drop(['mn_ISO', 'mn_Country'], axis=1, inplace=True)

# %%
subnat_info[[key for key in subnat_info.keys() if 'mpi' in key.lower()]].head(5)
# Out:
#    mpi_national  mpi_regional  mn_MPI Urban  mn_MPI Rural
# 0         0.295         0.387         0.132         0.347
# 1         0.295         0.466         0.132         0.347
# 2         0.295         0.300         0.132         0.347
# 3         0.295         0.301         0.132         0.347
# 4         0.295         0.325         0.132         0.347

# %% [markdown]
# All mpi values look to be different, so I'll keep all of them

# %%
subnat_info[[key for key in subnat_info.keys() if 'head' in key.lower()]].head(5)
# Out:
#    headcount_ratio_regional  mn_Headcount Ratio Urban  \
# 0                      67.5                      28.8
# 1                      79.3                      28.8
# 2                      59.7                      28.8
# 3                      55.7                      28.8
# 4                      61.0                      28.8
#
#    mn_Headcount Ratio Rural
# 0                     64.66
# 1                     64.66
# 2                     64.66
# 3                     64.66
# 4                     64.66

# %% [markdown]
# Headcount values all different, so I'll keep them all

# %%
subnat_info[[key for key in subnat_info.keys() if 'intens' in key.lower()]].head(5)
# Out:
#    intensity_of_deprivation_regional  mn_Intensity of Deprivation Urban  \
# 0                               57.3                               45.8
# 1                               58.8                               45.8
# 2                               50.3                               45.8
# 3                               54.1                               45.8
# 4                               53.3                               45.8
#
#    mn_Intensity of Deprivation Rural
# 0                               53.6
# 1                               53.6
# 2                               53.6
# 3                               53.6
# 4                               53.6

# %% [markdown]
# Deprivation intensity also unique, so keep them all.
#
# Rename new features so they have better names

# %%
import re
rn_lam = lambda colname: colname[3:].lower().replace(' ', '_') if re.match('mn_.*', colname) is not None else colname
subnat_info.rename(rn_lam, axis=1, inplace=True)
subnat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 983
# Data columns (total 18 columns):
# locationname                         984 non-null object
# geo                                  984 non-null object
# lat                                  892 non-null float64
# lon                                  892 non-null float64
# mpi_national                         984 non-null float64
# headcount_ratio_regional             984 non-null float64
# intensity_of_deprivation_regional    983 non-null float64
# country                              984 non-null object
# region                               984 non-null object
# world_region                         984 non-null object
# ISO                                  984 non-null object
# mpi_regional                         984 non-null float64
# mpi_urban                            984 non-null float64
# headcount_ratio_urban                984 non-null float64
# intensity_of_deprivation_urban       984 non-null float64
# mpi_rural                            984 non-null float64
# headcount_ratio_rural                984 non-null float64
# intensity_of_deprivation_rural       984 non-null float64
# dtypes: float64(12), object(6)
# memory usage: 146.1+ KB

# %% [markdown]
# This dataset looks good, I will now run through a small procedure of ensuring that if the `subnat_region` feature I added is not in this new dataset (meaning there is not a matching region and country), then I will change the subnat_region to just be the region, in case it produced a value that it can't use anyways.

# %%
subnat_not_in_mpi = kiva_subnat_loans[['country','subnat_region']].apply(tuple, axis=1).isin(subnat_info[['country', 'region']].apply(tuple, axis=1))
subnat_not_in_mpi.describe()
# Out:
# count     671205
# unique         2
# top        False
# freq      594868
# dtype: object

# %%
region_not_in_mpi = kiva_subnat_loans[['country','region']].apply(tuple, axis=1).isin(subnat_info[['country', 'region']].apply(tuple, axis=1))
region_not_in_mpi.describe()
# Out:
# count     671205
# unique         2
# top        False
# freq      620250
# dtype: object

# %%
kiva_subnat_loans[~subnat_not_in_mpi][['country','subnat_region']]
# Out:
#             country             subnat_region
# 2             India               West Bengal
# 5             Kenya                       NaN
# 6             India               West Bengal
# 14            India               West Bengal
# 18            India               West Bengal
# 25            India               West Bengal
# 26            India               West Bengal
# 28            India               West Bengal
# 29            India               West Bengal
# 33            India               West Bengal
# 45            India               West Bengal
# 46            Kenya                       Voi
# 47            India               West Bengal
# 49      El Salvador                       NaN
# 50         Tanzania             Dar es Salaam
# 51      Philippines       Zamboanga del Norte
# 52      Philippines           Negros Oriental
# 54          Senegal                       NaN
# 55      Philippines                   Palawan
# 56      Philippines           Negros Oriental
# 57            Kenya                   Mombasa
# 58            Kenya                   Mombasa
# 59         Tanzania             Dar es Salaam
# 60         Cambodia            Takeo province
# 61          Liberia                   New Kru
# 62          Vietnam                 Hai Duong
# 64         Cambodia  Kampong Chhnang Province
# 65      Philippines                   Isabela
# 66          Liberia                Logan Town
# 67            Kenya                       NaN
# ...             ...                       ...
# 671174        Kenya                       NaN
# 671175       Mexico                 Iztacalco
# 671176        Ghana                     Accra
# 671177        Kenya                       NaN
# 671178        Kenya                       NaN
# 671179     Paraguay                Concepción
# 671180      Bolivia                    La Paz
# 671182       Mexico                 Iztacalco
# 671183       Mexico                 Iztacalco
# 671184      Bolivia                    La Paz
# 671185        Kenya                       NaN
# 671186     Paraguay                Concepción
# 671187        Kenya                       NaN
# 671188        Ghana                     Accra
# 671189        Kenya                       NaN
# 671190        Kenya                       NaN
# 671191      Bolivia                    La Paz
# 671192      Bolivia                    La Paz
# 671193       Mexico                 Iztacalco
# 671194        Kenya                       NaN
# 671195        Ghana                     Accra
# 671196        Ghana                     Accra
# 671197        Kenya                       NaN
# 671198       Mexico                 Iztacalco
# 671199     Paraguay                Concepción
# 671200     Paraguay                Concepción
# 671201        Kenya                       NaN
# 671202        Kenya                       NaN
# 671203        Kenya                       NaN
# 671204        Kenya                       NaN
#
# [594868 rows x 2 columns]

# %%
subnat_info[subnat_info['country'] == 'Paraguay'][['country', 'region']]
# Out:
# Empty DataFrame
# Columns: [country, region]
# Index: []

# %%
kiva_loans_mpi_nat = kiva_loans.merge(mpi_nat, how='left', left_on='country', right_on='mpi_nat-Country')
kiva_loans_mpi_nat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 67 columns):
# id                                        671205 non-null int64
# funded_amount                             671205 non-null float64
# loan_amount                               671205 non-null float64
# activity                                  671205 non-null object
# sector                                    671205 non-null object
# use                                       666973 non-null object
# country_code                              671197 non-null object
# country                                   671205 non-null object
# region                                    614405 non-null object
# currency                                  671205 non-null object
# partner_id                                657698 non-null float64
# posted_time                               671205 non-null datetime64[ns]
# disbursed_time                            668809 non-null datetime64[ns]
# funded_time                               622874 non-null datetime64[ns]
# term_in_months                            671205 non-null float64
# lender_count                              671205 non-null int64
# tags                                      671205 non-null object
# borrower_genders                          671205 non-null object
# repayment_interval                        671205 non-null object
# date                                      671205 non-null datetime64[ns]
# time_till_funded                          622874 non-null timedelta64[ns]
# hours_till_funded                         622874 non-null float64
# tag_#Fabrics                              671205 non-null int64
# tag_#Supporting Family                    671205 non-null int64
# tag_#Inspiring Story                      671205 non-null int64
# tag_#Single Parent                        671205 non-null int64
# tag_#First Loan                           671205 non-null int64
# tag_#Woman Owned Biz                      671205 non-null int64
# tag_#Technology                           671205 non-null int64
# tag_#Hidden Gem                           671205 non-null int64
# tag_#Eco-friendly                         671205 non-null int64
# tag_#Repeat Borrower                      671205 non-null int64
# tag_#Single                               671205 non-null int64
# tag_#Widowed                              671205 non-null int64
# tag_#Low-profit FP                        671205 non-null int64
# tag_#Repair Renew Replace                 671205 non-null int64
# tag_#Elderly                              671205 non-null int64
# tag_#Interesting Photo                    671205 non-null int64
# tag_#Refugee                              671205 non-null int64
# tag_#Tourism                              671205 non-null int64
# tag_#Schooling                            671205 non-null int64
# tag_#Female Education                     671205 non-null int64
# tag_user_favorite                         671205 non-null int64
# tag_#Biz Durable Asset                    671205 non-null int64
# tag_#Parent                               671205 non-null int64
# tag_#Sustainable Ag                       671205 non-null int64
# tag_#Job Creator                          671205 non-null int64
# tag_volunteer_like                        671205 non-null int64
# tag_volunteer_pick                        671205 non-null int64
# tag_#Unique                               671205 non-null int64
# tag_#Animals                              671205 non-null int64
# tag_#Orphan                               671205 non-null int64
# tag_user_like                             671205 non-null int64
# tag_#Vegan                                671205 non-null int64
# tag_#Trees                                671205 non-null int64
# tag_#Health and Sanitation                671205 non-null int64
# tag_#Post-disbursed                       671205 non-null int64
# num_male_borrowers                        671205 non-null int64
# num_female_borrowers                      671205 non-null int64
# mpi_nat-ISO                               590440 non-null object
# mpi_nat-Country                           590440 non-null object
# mpi_nat-MPI Urban                         590440 non-null float64
# mpi_nat-Headcount Ratio Urban             590440 non-null float64
# mpi_nat-Intensity of Deprivation Urban    590440 non-null float64
# mpi_nat-MPI Rural                         590440 non-null float64
# mpi_nat-Headcount Ratio Rural             590440 non-null float64
# mpi_nat-Intensity of Deprivation Rural    590440 non-null float64
# dtypes: datetime64[ns](4), float64(11), int64(39), object(12), timedelta64[ns](1)
# memory usage: 348.2+ MB

# %%
mpi_subnat = mpi_subnat_orig.rename(lambda x: 'mpi_sub-' + str(x), axis=1)
mpi_subnat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 8 columns):
# mpi_sub-ISO country code                     984 non-null object
# mpi_sub-Country                              984 non-null object
# mpi_sub-Sub-national region                  984 non-null object
# mpi_sub-World region                         984 non-null object
# mpi_sub-MPI National                         984 non-null float64
# mpi_sub-MPI Regional                         984 non-null float64
# mpi_sub-Headcount Ratio Regional             984 non-null float64
# mpi_sub-Intensity of deprivation Regional    983 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 61.6+ KB

# %%
kiva_loans_mpi = kiva_loans_mpi_nat.merge(mpi_subnat, how='left', left_on=['region','country'], right_on=['mpi_sub-Sub-national region', 'mpi_sub-Country'])
kiva_loans_mpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 75 columns):
# id                                           671205 non-null int64
# funded_amount                                671205 non-null float64
# loan_amount                                  671205 non-null float64
# activity                                     671205 non-null object
# sector                                       671205 non-null object
# use                                          666973 non-null object
# country_code                                 671197 non-null object
# country                                      671205 non-null object
# region                                       614405 non-null object
# currency                                     671205 non-null object
# partner_id                                   657698 non-null float64
# posted_time                                  671205 non-null datetime64[ns]
# disbursed_time                               668809 non-null datetime64[ns]
# funded_time                                  622874 non-null datetime64[ns]
# term_in_months                               671205 non-null float64
# lender_count                                 671205 non-null int64
# tags                                         671205 non-null object
# borrower_genders                             671205 non-null object
# repayment_interval                           671205 non-null object
# date                                         671205 non-null datetime64[ns]
# time_till_funded                             622874 non-null timedelta64[ns]
# hours_till_funded                            622874 non-null float64
# tag_#Fabrics                                 671205 non-null int64
# tag_#Supporting Family                       671205 non-null int64
# tag_#Inspiring Story                         671205 non-null int64
# tag_#Single Parent                           671205 non-null int64
# tag_#First Loan                              671205 non-null int64
# tag_#Woman Owned Biz                         671205 non-null int64
# tag_#Technology                              671205 non-null int64
# tag_#Hidden Gem                              671205 non-null int64
# tag_#Eco-friendly                            671205 non-null int64
# tag_#Repeat Borrower                         671205 non-null int64
# tag_#Single                                  671205 non-null int64
# tag_#Widowed                                 671205 non-null int64
# tag_#Low-profit FP                           671205 non-null int64
# tag_#Repair Renew Replace                    671205 non-null int64
# tag_#Elderly                                 671205 non-null int64
# tag_#Interesting Photo                       671205 non-null int64
# tag_#Refugee                                 671205 non-null int64
# tag_#Tourism                                 671205 non-null int64
# tag_#Schooling                               671205 non-null int64
# tag_#Female Education                        671205 non-null int64
# tag_user_favorite                            671205 non-null int64
# tag_#Biz Durable Asset                       671205 non-null int64
# tag_#Parent                                  671205 non-null int64
# tag_#Sustainable Ag                          671205 non-null int64
# tag_#Job Creator                             671205 non-null int64
# tag_volunteer_like                           671205 non-null int64
# tag_volunteer_pick                           671205 non-null int64
# tag_#Unique                                  671205 non-null int64
# tag_#Animals                                 671205 non-null int64
# tag_#Orphan                                  671205 non-null int64
# tag_user_like                                671205 non-null int64
# tag_#Vegan                                   671205 non-null int64
# tag_#Trees                                   671205 non-null int64
# tag_#Health and Sanitation                   671205 non-null int64
# tag_#Post-disbursed                          671205 non-null int64
# num_male_borrowers                           671205 non-null int64
# num_female_borrowers                         671205 non-null int64
# mpi_nat-ISO                                  590440 non-null object
# mpi_nat-Country                              590440 non-null object
# mpi_nat-MPI Urban                            590440 non-null float64
# mpi_nat-Headcount Ratio Urban                590440 non-null float64
# mpi_nat-Intensity of Deprivation Urban       590440 non-null float64
# mpi_nat-MPI Rural                            590440 non-null float64
# mpi_nat-Headcount Ratio Rural                590440 non-null float64
# mpi_nat-Intensity of Deprivation Rural       590440 non-null float64
# mpi_sub-ISO country code                     50955 non-null object
# mpi_sub-Country                              50955 non-null object
# mpi_sub-Sub-national region                  50955 non-null object
# mpi_sub-World region                         50955 non-null object
# mpi_sub-MPI National                         50955 non-null float64
# mpi_sub-MPI Regional                         50955 non-null float64
# mpi_sub-Headcount Ratio Regional             50955 non-null float64
# mpi_sub-Intensity of deprivation Regional    50952 non-null float64
# dtypes: datetime64[ns](4), float64(15), int64(39), object(16), timedelta64[ns](1)
# memory usage: 389.2+ MB

# %%
unique_reg_con_pairs = kiva_loans_mpi[['region', 'country']].drop_duplicates()

# %%
unique_reg_con_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12821 entries, 0 to 670844
# Data columns (total 2 columns):
# region     12749 non-null object
# country    12821 non-null object
# dtypes: object(2)
# memory usage: 300.5+ KB

# %% [markdown]
# The reason I got the list above is that I can use it to create a dataset that would allow me to map a region and country to a more appropriate subnational region that is more likely to have an associated MPI

# %% [markdown]
# ```python
# from functools import lru_cache
# import re
#
# api_key = 'AIzaSyBoSQjjGx7kN4XfhLieSBsJIOoAYfO2wBo'
# autocomp_addr = 'https://maps.googleapis.com/maps/api/place/autocomplete/json?key=' + api_key + '&input='
# search_addr = 'https://maps.googleapis.com/maps/api/place/textsearch/json?key=' + api_key + '&query='
#
# s = reqs.Session()
#
# #Caching not needed since each entry is unique
# #@lru_cache(maxsize=None)
# def get_subregion(region, country, verbose=False):
#     search = str(region) + ' ' + str(country)
#     if verbose:
#         print(search)
#     if not (isinstance(region, str) and isinstance(country, str)):
#         return region
#     search = search.replace(' ', '+')
#     resp = s.get(search_addr + search).json()
#     if (resp['status'] != 'OK'):
#         if verbose:
#             print('\t', resp)
#         suggest_resp = s.get(autocomp_addr + search).json()
#         if (suggest_resp['status'] != 'OK'):
#             if verbose:
#                 print('\tFAILED TO FIND', search)
#                 print('\t', suggest_resp)
#             return region
#         pred = suggest_resp['predictions'][0]['description']
#         search = pred.replace(',', '').replace(' ', '+')
#         if verbose:
#             print('\tDid you mean "', search, '"?')
#         resp = s.get(search_addr + search).json()
#         if (resp['status'] != 'OK'):
#             if verbose:
#                 print('\tFAILED TO FIND', search)
#                 print('\t', resp)
#             return region
#     res0 = resp['results'][0]
#     if 'formatted_address' not in res0:
#         return region
#     addr = res0['formatted_address'].split(', ')
#     if len(addr) > 1:
#         ret = addr[-2]
#         return re.sub('\d+$', '', ret).strip()
#     return region
#
# unique_reg_con_pairs['subnat_region'] = unique_reg_con_pairs.apply(tuple, axis=1).apply(lambda x: get_subregion(*x))
# unique_reg_con_pairs.to_csv('subnat_regions.csv')
# ```

# %%
from functools import lru_cache
import requests as reqs

api_key = 'AIzaSyBse-g-j8WU99QqOnAtE1j4REMzrX9bwKw'

@lru_cache(maxsize=None)
def get_subregion(region, country):
    try:
        search = '+'.join(region.split(' ') + country.split(' '))
    except:
        print(type(region), region, sep=": ")
        print(str(region) == 'nan')
        print(type(country), country, sep=": ")
        return region
    print(search)
    resp = reqs.get('https://www.google.com/maps/search/' + search + '/')
    print(resp)
    cache_resp = ''
    for i in resp.iter_lines():
        i = i.decode('ascii', errors='backslashreplace').strip()
        if i.startswith('cacheResponse'):
            cache_resp = i[14:-2]
            break
    m = re.search('(?<=")[\w\s]*(, )?(?P<subregion>[\w]+), ' + country + '(?=")', cache_resp)
    return m.group(m.lastgroup)


    
#kiva_loans_mpi[['region', 'country']].apply(tuple, axis=1).apply(lambda x: get_subregion(*x))

# %%
# Out:
# 'Sindh'

# %%
cache_resp = None
for i in resp.iter_lines():
    i = i.decode('ascii', errors='backslashreplace').strip()
    if i.startswith('cacheResponse'):
        cache_resp = i[14:-2]
        break
print(cache_resp)
# Out:
# [[[52525.68908656373,70.65149819999999,30.04420025],[0,0,0],[1024,730],13.10000038146973],"/maps-lite/js/2/ml_20180417_0",107,"!1b0!2b1!3s!4b1!5b0!6b1!7s!8b1!9i0!10b1!11b1!13b0!14b0!15b0!16b0!17b1!18b1!19b0!20b0!21b0!22s1!23zMSwxNywxOCwy!24s!25s!26b0!27b0!28b0!29i2000!30b1!32b0!34i0!36b0!37sNONE!38b0!39b1!40b0!41i0!42s!43b0!44i0!45i3600!46i0!47i10!48b1!49b0!50b0!52i0!53i2000000000!54b0!58i0!60i0!61i0!62b0!63b1",null,["en","us"],["/maps/lite/ApplicationService.GetEntityDetails","/maps/lite/ApplicationService.UpdateStarring","/maps/lite/ApplicationService.Search",null,"/maps/lite/suggest","/maps/lite/directions","/maps/lite/MapsLiteService.GetHotelAvailability","/maps/lite/MapsLiteService.GetSharedLocations","https://www.google.com/maps/api/js/reviews?key=AIzaSyCNWEtGyeVduDK_k5UOq8iBk-qP8G4TJL0\u0026language=en","/maps/lite/reviews","/maps/timeline/_rpc/mas","/maps/timeline/_rpc/pc","//maps.gstatic.com","//www.gstatic.com","/maps/preview/placeactions/writeaction"],[[[2,"spotlight",null,null,null,null,null,[[null,null,null,null,null,null,null,null,null,null,null,[null,null,null,null,null,null,null,null,null,0,null,"placeholder",null,null,null,null,null,null,[0,"5,6,24,45,75,93",["0x0:0x1c9ef8b4f921afbb"]],1]],["0x393ab1e92cff6575:0x1c9ef8b4f921afbb","Dera Ghazi Khan, Punjab, Pakistan",null,[null,null,30.0489423,70.645473],1,1],null,null,null,null,null,null,null,null,10,null,[null,"a",null,null,null,null,null,null,null,null,null,null,null,1,null,null,null,[null,null,null,null,0,0,null,0,1],null,null,null,[null,null,null,null,null,2,3,2]],1,null,null,null,null,[14,29]]]],[[52]]],[["0x393ab1e92cff6575:0x1c9ef8b4f921afbb","Dera Ghazi Khan, Punjab, Pakistan",[30.0489423,70.645473]],"Dera Ghazi Khan",["Punjab","Pakistan"],null,null,null,null,null,null,null,null,null,null,"Dera Ghazi Khan, Punjab, Pakistan",null,null,[[[null,[3,"-NP-uA_fC__w/Wow5HRROZVI/AAAAAAAAYbc/hmDBkP-gl-MFA6R6qHHkU1INeT-sOTFwwCLIBGAYYCw"],[3,3,[1600,1200]],null,[null,[[["A Tabi"],"//maps.google.com/maps/contrib/103633467204177734000/photos","//lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/s100-p-k-no-mo/p.jpg",null,null,"103633467204177734000"]],null,[[null,"//picasaweb.google.com/","//maps.gstatic.com/tactile/fineprint/picasa_logo-1x.png"]],[[null,"https://picasaweb.google.com/lh/sredir?uname=103633467204177734000\u0026id=6524652757210522962\u0026target=PHOTO"]]],[[[2],[[null,null,30.05304896449588,70.63709299747023]]]],[2,null,null,[2],2,[null,null,"photos:gmm_android",[6,7,4,1,3]]]],[[3,70.63709299747023,30.05304896449588],[0,90],[1200,1600],75],["//lh6.googleusercontent.com/-NP-uA_fC__w/Wow5HRROZVI/AAAAAAAAYbc/hmDBkP-gl-MFA6R6qHHkU1INeT-sOTFwwCLIBGAYYCw/w376-h501-k-no/","Photos",[1200,1600],[376,111]],12,"0ahUKEwjhrbqlqs_aAhVMrVkKHSRwDWkQzCcICCgAMAA"]],null,null,[null,null,null,null,null,null,null,1],null,null,null,1,1,null,null,"ChIJdWX_LOmxOjkRu68h-bT4nhw",null,null,"0ahUKEwjhrbqlqs_aAhVMrVkKHSRwDWkQ8BcIAygAMAA","\xda\x88\xdb\x8c\xd8\xb1\xdb\x81 \xd8\xba\xd8\xa7\xd8\xb2\xdb\x8c \xd8\xae\xd8\xa7\xd9\x86",[[[null,[3,"-J7nFuiABEvM/WHcF3D84WgI/AAAAAAAAASw/0XfEU96IOigOsWaFmW5eOtGJ_JffCBrXQCLIB"],[3,3,[1280,960]],null,[null,[[["Saleem Zaman"],"//maps.google.com/maps/contrib/101248067599005999052/photos","//lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/s100-p-k-no-mo/p.jpg",null,null,"101248067599005999052"]],null,[[null,"//picasaweb.google.com/","//maps.gstatic.com/tactile/fineprint/picasa_logo-1x.png"]],[[null,"https://picasaweb.google.com/lh/sredir?uname=101248067599005999052\u0026id=6374570241077828098\u0026target=PHOTO"]]],[[[2],[[null,null,30.05304896449588,70.63709299747023]]]],[2,null,null,[2],2,[null,null,"photos:gmm_android",[6,7,4,1,3]]]],[[3,70.63709299747023,30.05304896449588],[0,90],[960,1280],75],["//lh3.googleusercontent.com/-J7nFuiABEvM/WHcF3D84WgI/AAAAAAAAASw/0XfEU96IOigOsWaFmW5eOtGJ_JffCBrXQCLIB/w408-h544-k-no/","D G Khan",[960,1280],[408,256]],12,"0ahUKEwjhrbqlqs_aAhVMrVkKHSRwDWkQzCcICygEM ...

# %%
import re

country = 'Pakistan'
m = re.search('(?<=")[\w\s]*(, )?(?P<subregion>[\w]+), ' + country + '(?=")', cache_resp)

# %%
m.group(m.lastgroup)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-285-451e9100b70c> in <module>()
# ----> 1 str(m.match)
#
# AttributeError: '_sre.SRE_Match' object has no attribute 'match'

# %% [markdown]
# - mpi_LocationName: Not very useful with country and region features
# - mpi_ISO: Similar to country_code, not very useful
# - mpi_country: Same as country on `kiva_loans`
# - mpi_region: Same as region on `kiva_loans`
# - mpi_world_region: more broad than country, 6 values, could be useful in identifying global trends
# - mpi_MPI: very useful for welfare, provides metric to the region for general poverty
# - mpi_geo: basically useless with lat and lon features
# - mpi_lat: might be useful to find linear trends with lat & lon, but not a very good metric for region based things
# - mpi_lon: same as lat

# %%
kiva_mpi = kiva_mpi[pd.notnull(kiva_mpi['mpi_MPI'])]

# %%
kiva_mpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984 entries, 0 to 1007
# Data columns (total 9 columns):
# mpi_LocationName    984 non-null object
# mpi_ISO             984 non-null object
# mpi_country         984 non-null object
# mpi_region          984 non-null object
# mpi_world_region    984 non-null object
# mpi_MPI             984 non-null float64
# mpi_geo             984 non-null object
# mpi_lat             892 non-null float64
# mpi_lon             892 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 76.9+ KB

# %%
kiva_loans_mpi = kiva_loans.merge(kiva_mpi, how='left', left_on=['region', 'country'], right_on=['mpi_region', 'mpi_country'])

# %%
kiva_loans_mpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671205 entries, 0 to 671204
# Data columns (total 68 columns):
# id                            671205 non-null int64
# funded_amount                 671205 non-null float64
# loan_amount                   671205 non-null float64
# activity                      671205 non-null object
# sector                        671205 non-null object
# use                           666973 non-null object
# country_code                  671197 non-null object
# country                       671205 non-null object
# region                        614405 non-null object
# currency                      671205 non-null object
# partner_id                    657698 non-null float64
# posted_time                   671205 non-null datetime64[ns]
# disbursed_time                668809 non-null datetime64[ns]
# funded_time                   622874 non-null datetime64[ns]
# term_in_months                671205 non-null float64
# lender_count                  671205 non-null int64
# tags                          671205 non-null object
# borrower_genders              671205 non-null object
# repayment_interval            671205 non-null object
# date                          671205 non-null datetime64[ns]
# time_till_funded              622874 non-null timedelta64[ns]
# hours_till_funded             622874 non-null float64
# tag_#Fabrics                  671205 non-null int64
# tag_#Supporting Family        671205 non-null int64
# tag_#Inspiring Story          671205 non-null int64
# tag_#Single Parent            671205 non-null int64
# tag_#First Loan               671205 non-null int64
# tag_#Woman Owned Biz          671205 non-null int64
# tag_#Technology               671205 non-null int64
# tag_#Hidden Gem               671205 non-null int64
# tag_#Eco-friendly             671205 non-null int64
# tag_#Repeat Borrower          671205 non-null int64
# tag_#Single                   671205 non-null int64
# tag_#Widowed                  671205 non-null int64
# tag_#Low-profit FP            671205 non-null int64
# tag_#Repair Renew Replace     671205 non-null int64
# tag_#Elderly                  671205 non-null int64
# tag_#Interesting Photo        671205 non-null int64
# tag_#Refugee                  671205 non-null int64
# tag_#Tourism                  671205 non-null int64
# tag_#Schooling                671205 non-null int64
# tag_#Female Education         671205 non-null int64
# tag_user_favorite             671205 non-null int64
# tag_#Biz Durable Asset        671205 non-null int64
# tag_#Parent                   671205 non-null int64
# tag_#Sustainable Ag           671205 non-null int64
# tag_#Job Creator              671205 non-null int64
# tag_volunteer_like            671205 non-null int64
# tag_volunteer_pick            671205 non-null int64
# tag_#Unique                   671205 non-null int64
# tag_#Animals                  671205 non-null int64
# tag_#Orphan                   671205 non-null int64
# tag_user_like                 671205 non-null int64
# tag_#Vegan                    671205 non-null int64
# tag_#Trees                    671205 non-null int64
# tag_#Health and Sanitation    671205 non-null int64
# tag_#Post-disbursed           671205 non-null int64
# num_male_borrowers            671205 non-null int64
# num_female_borrowers          671205 non-null int64
# mpi_LocationName              50955 non-null object
# mpi_ISO                       50955 non-null object
# mpi_country                   50955 non-null object
# mpi_region                    50955 non-null object
# mpi_world_region              50955 non-null object
# mpi_MPI                       50955 non-null float64
# mpi_geo                       50955 non-null object
# mpi_lat                       50953 non-null float64
# mpi_lon                       50953 non-null float64
# dtypes: datetime64[ns](4), float64(8), int64(39), object(16), timedelta64[ns](1)
# memory usage: 353.3+ MB

# %%
kiva_data['kiva_loans']['region'].unique()
# Out:
# array(['Lahore', 'Maynaguri', 'Abdul Hakeem', ..., 'Gbenikoro Village',
#        'Morimaraia', 'alejandria'], dtype=object)

# %%
import numpy as np
vec_lower = np.vectorize(str.lower)
kiva_data['kiva_mpi_region_locations']['country' and 'region'].unique()
# Out:
# array(['Badakhshan', 'Badghis', 'Baghlan', 'Balkh', 'Bamyan', 'Daykundi',
#        'Farah', 'Faryab', 'Ghazni', 'Ghor', 'Helmand', 'Herat', 'Jawzjan',
#        'Kabul', 'Kandahar', 'Kapisa', 'Khost', 'Kunarha', 'Kunduz',
#        'Laghman', 'Logar', 'Nangarhar', 'Nimroz', 'Nooristan', 'Paktika',
#        'Paktya', 'Panjsher', 'Parwan', 'Samangan', 'Sar-E-Pul', 'Takhar',
#        'Urozgan', 'Wardak', 'Zabul', nan, 'Bujumbura Mairie', 'Nord',
#        'Centre-Est', 'Ouest', 'Sud', 'Alibori', 'Atacora', 'Atlantique',
#        'Borgou', 'Collines', 'Couffo', 'Donga', 'Littoral', 'Mono',
#        'Ouðmð', 'Plateau', 'Zou', 'Boucle de mouhoun', 'Cascades',
#        'Centre', 'Centre-est', 'Centre-nord', 'Centre-ouest',
#        'Centre-sud', 'Est', 'Hauts basins', 'Plateau central', 'Sahel',
#        'Sud-ouest', 'Barisal', 'Chittagong', 'Dhaka', 'Khulna',
#        'Rajshahi', 'Rangpur', 'Sylhet', 'Corozal', 'Orange Walk',
#        'Belize (excluding Belize City South Side)', 'Stann Creek',
#        'Toledo', 'Cayo', 'Belize City South Side', 'Chuquisaca', 'La Paz',
#        'Cochabamba', 'Oruro', 'Potosð', 'Tarija', 'Santa Cruz', 'Beni',
#        'Pando', 'Acre', 'Alagoas', 'Amapð', 'Amazonas', 'Bahia', 'Cearð',
#        'Distrito Federal', 'Espðrito Santo', 'Goiðs', 'Maranhðo',
#        'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Paranð',
#        'Paraðba', 'Parð', 'Pernambuco', 'Piauð', 'Rio Grande do Norte',
#        'Rio Grande do Sul', 'Rio de Janeiro', 'Rondðnia', 'Roraima',
#        'Santa Catarina', 'Sergipe', 'Sðo Paulo', 'Tocantins', 'Bumthang',
#        'Chukha', 'Dagana', 'Haa', 'Lhuntse', 'Mongar', 'Paro',
#        'Pemagatshel', 'Punakha', 'Samdrup Jongkhar', 'Samtse', 'Sarpang',
#        'Thimphu', 'Trashigang', 'Trashiyangtse', 'Trongsa', 'Tsirang',
#        'Wangdi', 'Zhemgang', "Ombella-M'poko", 'Lobaye', 'Mambðrð-Kadði',
#        'Nana-Mambðrð', 'Sangha-Mbaðrð', 'Ouham-Pendð', 'Ouham', 'Kðmo',
#        'Nana-Grðbizi', 'Ouaka', 'Haute-Kotto', 'Bamingui-Bangoran',
#        'Basse-Kotto', 'Mbomou', 'Haut-Mbomou', 'Bangui', 'East',
#        'Central', 'West', 'Centre-Nord', 'Centre-Ouest', 'Nord-Est',
#        'Nord-Ouest', 'Sud sans Abidjan', "Ville d'Abidjan", 'Adamaoua',
#        'Centre (sans Yaoundð)', 'Douala', 'Extrðme-Nord',
#        'Littoral (sans Douala)', 'Sud-Ouest', 'Yaoundð', 'Kinshasa',
#        'Bandundu', 'Bas-Congo', 'ðquateur', 'Kasað-Occidental',
#        'Kasað-Oriental', 'Katanga', 'Maniema', 'Nord-Kivu', 'Orientale',
#        'Sud-Kivu', 'Kouilou', 'Niari', 'Lðkoumou', 'Bouenza', 'Pool',
#        'Plateaux', 'Cuvette', 'Cuvette-Ouest', 'Sangha', 'Likouala',
#        'Brazzaville', 'Pointe-Noire', 'Guajira, Cesar, Magdalena',
#        'Barranquilla A. M.', 'Atlantico, San Andres, Bolivar Norte',
#        'Bolivar Sur, Sucre, Cordoba', 'Santanderes',
#        'Boyaca, Cmarca, Meta', 'Medellin A.M.', 'Antioquia Sin Medellin',
#        'Caldas, Risaralda, Quindio', 'Tolima, Huila, Caqueta',
#        'Cali A.M.', 'Valle Sin Cali Ni Litoral',
#        'Cauca Y Nariðo Sin Litoral', 'Litoral Pacifico', 'Bogota',
#        'Orinoquia Y Amazonia', 'Mwali (Mohðli)',
#        'Ndzuwani (Ndzouani or Anjouan)', 'Ngazidja (Grande Comore)',
#        'Djibouti', 'Other Districts', 'Cibao Nordeste', 'Cibao Noroeste',
#        'Cibao Norte', 'Cibao Sur', 'Del Yuma', 'El Valle', 'Enriquillo',
#        'Higuamo', 'Metropolitana', 'Valdesia', 'Mountains', 'Coast',
#        'Amazon', 'Galapagos Island', 'Cairo', 'Alexandria', 'Port Said',
#        'Suez', 'Damietta', 'Dakahlia', 'Sharkia', 'Kalyubia',
#        'Kafr El-Sheikh', 'Gharbia', 'Menoufia', 'Behera', 'Ismailia',
#        'Giza', 'Beni Suef', 'Fayoum', 'Menya', 'Assuit', 'Souhag', 'Qena',
#        'Aswan', 'Luxor', 'Red Sea', 'New Valley', 'Matroh', 'Tigray',
#        'Affar', 'Amhara', 'Oromiya', 'Somali', 'Benishangul-Gumuz',
#        "Southern Nations, Nationalities, and People's Region", 'Gambela',
#        'Harari', 'Addis Ababa', 'Dire Dawa', 'Libreville/Port-Gentil',
#        'Estuaire (sans Libreville)', 'Haut-Ogoouð', 'Moyen-Ogoouð',
#        'Ngounið', 'Nyanga', 'Ogoouð Maritime (sans Port-Gentil)',
#        'Ogoouð-Ivindo', 'Ogoouð-Lolo', 'Woleu-Nðtem', 'Ashanti',
#        'Brong Ahafo', 'Eastern', 'Greater Accra', 'Northern',
#        'Upper East', 'Upper West', 'Volta', 'Western', 'Bokð', 'Conakry',
#        'Faranah', 'Kankan', 'Kindia', 'Labð', 'Mamou', "N'Zðrðkorð",
#        'Banjul', 'Kanifing', 'Brikama', 'Mansakonko', 'Kerewan',
#        'Kuntaur', 'Janjanbureh', 'Basse', 'Bafata', 'Biombo', 'Bolama',
#        'Cacheu', 'Gabu', 'Oio', 'Quinara', 'Tombali', 'Sab',
#        'Alta Verapaz', 'Baja Verapaz', 'Chimaltenango', 'Chiquimula',
#        'El Progreso', 'Escuintla', 'Guatemala Municipio',
#        'Guatemala Resto', 'Huehuetenango', 'Izabal', 'Jalapa', 'Jutiapa',
#        'Peten', 'Quetzaltenango', 'Quiche', 'Retalhuleu', 'Sacatepequez',
#        'San Marcos', 'Santa Rosa', 'Solola', 'Suchitepequez',
#        'Totonicapan', 'Zacapa', 'Barima-Waini',
#        'Cuyuni-Mazaruni and Potaro-Siparuni', 'Demerara-Mahaica',
#        'East Berbice-Corentyne', 'Essequibo Islands-West Demerara',
#        'Mahaica-Berbice', 'Pomeroon-Supenaam', 'Upper Demerara-Berbice',
#        'Upper Takutu-Upper Essequibo', 'Atlðntida', 'Colðn', 'Comayagua',
#        'Copðn', 'Cortðs', 'Choluteca', 'El Paraðso', 'Francisco Morazðn',
#        'Gracias a Dios', 'Intibucð', 'Islas de la Bahða', 'Lempira',
#        'Ocotepeque', 'Olancho', 'Santa Bðrbara', 'Valle', 'Yoro',
#        'Aire Mðtropolitaine/Reste-Ouest', 'Sud-Est', 'Artibonite',
#        'Grande-Anse', 'Nippes', 'Aceh', 'North Sumatera', 'West Sumatera',
#        'Riau', 'Jambi', 'South Sumatera', 'Bengkulu', 'Lampung',
#        'Bangka Belitung', 'Riau Islands', 'DKI Jakarta', 'West Java',
#        'Central Java', 'DI Yogyakarta', 'East Java', 'Banten', 'Bali',
#        'West Nusa Tenggara', 'East Nusa Tenggara', 'West Kalimantan',
#        'Central Kalimantan', 'South Kalimantan', 'East Kalimantan',
#        'North Sulawesi', 'Central Sulawesi', 'South Sulawesi',
#        'Southeast Sulawesi', 'Gorontalo', 'West Sulawesi', 'Maluku',
#        'North Maluku', 'West Papua', 'Papua', 'Dohuk', 'Ninewa',
#        'Suleimaniya', 'Kirkuk', 'Erbil', 'Diyala', 'Al-Anbar', 'Baghdad',
#        'Babil', 'Karbala', 'Wasit', 'Salahaddin', 'Al-Najaf',
#        'Al-Qadisiya', 'Al-Muthanna', 'Thi-Qar', 'Missan', 'Basrah',
#        'Kingston', 'St.  Andrew', 'St. Thomas', 'Portland', 'St. Mary',
#        'St. Ann', 'Trelawny', 'St. James', 'Hanover', 'Westmoreland',
#        'St. Elizabeth', 'Manchester', 'Clarendon', 'St. Catherine',
#        'North', 'South', 'Nairobi', 'North Eastern', 'Nyanza',
#        'Rift Valley', 'Banteay Mean Chey', 'Battambang & Pailin',
#        'Kampong Cham', 'Kampong Chhnang', 'Kampong Speu', 'Kampong Thom',
#        'Kampot & Kep', 'Kandal', 'Kratie', 'Mondol Kiri & Rattanak Kiri',
#        'Otdar Mean Chey', 'Phnom Penh', 'Preah Sihanouk & Kaoh Kong',
#        'Preah Vihear & Steung Treng', 'Prey Veng', 'Pursat', 'Siem Reap',
#        'Svay Rieng', 'Takeo', 'Vientiane Capital', 'Phongsaly',
#        'Luangnamtha', 'Oudomxay', 'Bokeo', 'Luangprabang', 'Huaphanh',
#        'Xayabury', 'Xiengkhuang', 'Vientiane', 'Borikhamxay', 'Khammuane',
#        'Savannakhet', 'Saravane', 'Sekong', 'Champasack', 'Attapeu',
#        'Bomi', 'Bong', 'Gbarpolu', 'Grand Bassa', 'Grand Cape Mount',
#        'Grand Gedeh', 'Grand Kru', 'Lofa', 'Margibi', 'Maryland',
#        'Montserrado', 'Nimba', 'River Cess', 'River Gee', 'Sinoe',
#        'Berea', 'Botha-Bothe', 'Leribe', 'Mafeteng', 'Maseru',
#        "Mohale'S Hoek", 'Mokhotlong', "Qacha'S-Nek", 'Quthing',
#        'Thaba Tseka', 'Sahara', 'Souss-Massa-Draa',
#        'El Gharb-Chrarda Bni Hssen', 'Chaouia Ourdigha',
#        'Marrakech-Tensift-El Haouz', 'Rðgion Oriental',
#        'Grand Casablanca', 'Rabat-Salð-Zemmour-Zair', 'Doukkala-Abda',
#        'Tadla-Azilal', 'Meknes-Tafilalet', 'Fes-Boulemane',
#        'Taza-Al Hoceima-Taounate', 'Tanger-Tetouan', 'Analamanga',
#        'Vakinankaratra', 'Itasy', 'Bongolava', 'Haute Matsiatra',
#        "Anamoroni'i Mania", 'Vatovavy Fitovinany', 'Ihorombe',
#        'Atsimo Atsinanana', 'Atsinanana', 'Analanjirofo',
#        'Alaotra Mangoro', 'Boeny', 'Sofia', 'Betsiboka', 'Melaky',
#        'Atsimo Andrefana', 'Androy', 'Anosy', 'Menabe', 'Diana', 'Sava',
#        'Kayes', 'Koulikoro', 'Sikasso', 'Sðgou', 'Mopti', 'Bamako',
#        'Ayeyarwaddy', 'Bago', 'Chin', 'Kachin', 'Kayah', 'Kayin',
#        'Magway', 'Mandalay', 'Mon', 'Naypyitaw', 'Rakhine', 'Sagaing',
#        'Shan', 'Taninthayi', 'Yangon', 'Khangai', 'Ulaanbaatar', 'Niassa',
#        'Cabo Delgado', 'Nampula', 'Zambðzia', 'Tete', 'Manica', 'Sofala',
#        'Inhambane', 'Gaza', 'Maputo Provðncia', 'Maputo Cidade',
#        'Hodh Charghy', 'Hodh Gharby', 'Assaba', 'Gorgol', 'Brakna',
#        'Trarza', 'Adrar', 'Dakhlett Nouadibou', 'Tagant', 'Guidimagha',
#        'Tirs-Ezemour', 'Nouakchott', 'Balaka', 'Blantyre City',
#        'Blantyre Rural', 'Chikwawa', 'Chitipa', 'Chradzulu', 'Dedza',
#        'Dowa', 'Karonga', 'Kasungu', 'Likoma', 'Lilongwe City',
#        'Lilongwe Rural', 'Machinga', 'Mangochi', 'Mchinji', 'Mulange',
#        'Mwanza', 'Mzimba', 'Mzuzu City', 'Ndanje', 'Neno', 'Nkhatabay',
#        'Nkhota Kota', 'Ntcheu', 'Ntchisi', 'Phalombe', 'Rumphi', 'Salima',
#        'Thyolo', 'Zomba City', 'Zomba Rural', 'Caprivi', 'Erongo',
#        'Hardap', 'Karas', 'Kavango', 'Khomas', 'Kunene', 'Ohangwena',
#        'Omaheke', 'Omusati', 'Oshana', 'Oshikoto', 'Otjozondjupa',
#        'Agadez', 'Diffa', 'Dosso', 'Maradi', 'Tahoua', 'Tillaberi',
#        'Zinder', 'Niamey', 'Sokoto', 'Zamfara', 'Katsina', 'Jigawa',
#        'Yobe', 'Borno', 'Adamawa', 'Gombe', 'Bauchi', 'Kano', 'Kaduna',
#        'Kebbi', 'Niger', 'FCT-Abuja', 'Nasarawa', 'Taraba', 'Benue',
#        'Kogi', 'Kwara', 'Oyo', 'Osun', 'Ekiti', 'Ondo', 'Edo', 'Anambra',
#        'Enugu', 'Ebonyi', 'Cross River', 'Akwa Ibom', 'Abia', 'Imo',
#        'Rivers', 'Bayelsa', 'Delta', 'Lagos', 'Ogun', 'Nueva Segovia',
#        'Jinotega', 'Madriz', 'Esteli', 'Chinandega', 'Leon', 'Matagalpa',
#        'Boaco', 'Managua', 'Masaya', 'Chontales', 'Granada', 'Carazo',
#        'Rivas', 'Rio San Juan', 'RAAN', 'RAAS', 'Central Hill',
#        'Central Mountain', 'Central Terai', 'Eastern Hill',
#        'Eastern Mountain', 'Eastern Terai', 'Far-Western Hill',
#        'Far-Western Mountain', 'Far-WesternTerai', 'MId-Western Hill',
#        'MId-Western Mountain', 'MId-WesternTerai', 'Western  Hill',
#        'Western  Terai', 'Western Mountain', 'Punjab', 'Sindh',
#        'Khyber Pakhtunkhwa', 'Balochistan', 'Gilgit Baltistan',
#        'Islamabad (ICT)', 'ðncash', 'Apurðmac', 'Arequipa', 'Ayacucho',
#        'Cajamarca', 'Callao', 'Cusco', 'Huancavelica', 'Huðnuco', 'Ica',
#        'Junðn', 'La Libertad', 'Lambayeque', 'Lima', 'Loreto',
#        'Madre de Dios', 'Moquegua', 'Pasco', 'Piura', 'Puno',
#        'San Martðn', 'Tacna', 'Tumbes', 'Ucayali',
#        'National Capital Region', 'Cordillera Admin Region',
#        'Ilocos Region', 'Cagayan Valley', 'Central Luzon', 'Calabarzon',
#        'Mimaropa', 'Bicol Region', 'Western Visayas', 'Central Visayas',
#        'Eastern Visayas', 'Zamboanga Peninsula', 'Northern Mindanao',
#        'Davao Peninsula', 'Soccsksargen', 'CARAGA', 'Armm', 'Kigali City',
#        'Blue Nile', 'Central Darfor', 'East Darfor', 'Gadarif', 'Gezira',
#        'Kassala', 'Khartoum', 'North Darfor', 'North Kordofan',
#        'River Nile', 'Sinnar', 'South Darfor', 'South Kordofan',
#        'West Darfor', 'West Kordofan', 'White Nile', 'Center', 'Kailahun',
#        'Kenema', 'Kono', 'Bombali', 'Kambia', 'Koinadugu', 'Port Loko',
#        'Tonkolili', 'Bo', 'Bonthe', 'Moyamba', 'Pujehun', 'Western Rural',
#        'Western Urban', 'Ahuachapan', 'Cabanas', 'Chalatenango',
#        'Cuscatlan', 'La Union', 'Morazan', 'San Miguel', 'San Salvador',
#        'San Vicente', 'Santa Ana', 'Sonsonate', 'Usulutan', 'Upper Nile',
#        'Jonglei and Unity', 'Warap', 'Northern Bahr el Ghazal',
#        'Western Bahr el Ghazal', 'Lakes', 'Western Equatoria',
#        'Central Equatoria', 'Eastern Equatoria',
#        'Regi\x8bo Autonoma de Principe', 'Regi\x8bo Centro Este',
#        'Regi\x8bo Norte Oeste', 'Regi\x8bo Sul Este', 'Paramaribo',
#        'Wanica', 'Nickerie', 'Coronie', 'Saramacca', 'Commewijne',
#        'Marowijne', 'Para', 'Brokopondo', 'Sipaliwini', 'Hhohho',
#        'Lubombo', 'Manzini', 'Shiselweni', 'Damascus', 'Halab',
#        'Rural Damascus', 'Hums', 'Hama', 'Latequia', 'Edlb', 'Hasaka',
#        'Dir Ezor', 'Tortous', 'Raqa', 'Daraa', 'As-swidaa', 'Qonitara',
#        'Barh El Gazal', 'Batha', 'Borkou/Tibesti', 'Chari Baguirmi',
#        'Ennedi', 'GuðRa', 'Hadjer-Lamis', 'Kanem', 'Lac',
#        'Logone Occidental', 'Logone Oriental', 'Mandoul',
#        'Mayo Kebbi Est', 'Mayo Kebbi Ouest', 'Moyen Chari', "N'DjamðNa",
#        'Ouaddað', 'Salamat', 'Sila', 'Tandjilð', 'Wadi Fira',
#        'Commune de Lome', 'Region Maritime', 'Region des Plateaux',
#        'Region Centrale', 'Region de la Kara', 'Region des Savanes',
#        'Dushanbe', 'Gorno-Badakhshan Autonomous Oblast', 'Sughd',
#        'Districts of Republican Subordination', 'Khatlon', 'Aileu',
#        'Ainaro', 'Baucau', 'Bobonaro', 'Cova Lima', 'Dili', 'Ermera',
#        'Liquica', 'Lautem', 'Manufahi', 'Manatuto', 'Oecussi', 'Viqueque',
#        'North West', 'North Central', 'South West', 'Tobago', 'Lake',
#        'South West Highlands', 'Southern', 'Southern Highlands',
#        'Zanzibar', 'Kampala', 'Central 1', 'Central 2', 'East Central',
#        'Karamoja', 'West Nile', 'Southwest', 'Central-Eastern',
#        'Tashkent', 'Red River Delta',
#        'Northern Midlands and Mountain area',
#        'North Central and Central Coastal area', 'Central Highlands',
#        'South East', 'Mekong River Delta', 'Ibb', 'Abyan', 'Sanaa City',
#        'Al-Baidha', 'Taiz', 'Al-Jawf', 'Hajjah', 'Al-Hodiedah',
#        'Hadramout', 'Dhamar', 'Shabwah', 'Sadah', 'Sanaa', 'Aden', 'Lahj',
#        'Mareb', 'Al-Mhweit', 'Al-Mhrah', 'Amran', 'Aldhalae', 'Reimah',
#        'Copperbelt', 'Luapula', 'Lusaka', 'Muchinga', 'North Western',
#        'Bulawayo', 'Harare', 'Manicaland', 'Mashonaland Central',
#        'Mashonaland East', 'Mashonaland West', 'Masvingo',
#        'Matabeleland North', 'Matabeleland South', 'Midlands'],
#       dtype=object)

# %%
import time as t

time_cols = ['posted_time', 'disbursed_time', 'funded_time', 'date']

for col in time_cols:
    kiva_loan_data_region[col] = pd.to_datetime(kiva_loan_data_region[col])
    print(kiva_loan_data_region[col][0])
# Out:
# 2014-01-02 14:25:08
# 2013-12-17 08:00:00
# 2014-01-08 22:07:48
# 2014-01-02 00:00:00

# %%
kiva_loan_data_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52197 entries, 0 to 52196
# Data columns (total 27 columns):
# id                    52197 non-null int64
# funded_amount         52197 non-null float64
# loan_amount           52197 non-null float64
# activity              52197 non-null object
# sector                52197 non-null object
# use                   52004 non-null object
# country_code          52197 non-null object
# country               52197 non-null object
# region                50955 non-null object
# currency              52197 non-null object
# partner_id            52197 non-null float64
# posted_time           52197 non-null datetime64[ns]
# disbursed_time        52197 non-null datetime64[ns]
# funded_time           48681 non-null datetime64[ns]
# term_in_months        52197 non-null float64
# lender_count          52197 non-null int64
# tags                  39273 non-null object
# borrower_genders      52005 non-null object
# repayment_interval    52197 non-null object
# date                  52197 non-null datetime64[ns]
# LocationName          50955 non-null object
# ISO                   52197 non-null object
# world_region          52197 non-null object
# MPI                   50955 non-null float64
# geo                   52197 non-null object
# lat                   50953 non-null float64
# lon                   50953 non-null float64
# dtypes: datetime64[ns](4), float64(7), int64(2), object(14)
# memory usage: 13.7+ MB

# %%
# %matplotlib inline
kiva_loan_data_region['geo'].describe()#.hist(xrot=90, figsize=(20, 7))
# Out:
# count                       52197
# unique                        109
# top       (10.5104642, 7.4165053)
# freq                        10000
# Name: geo, dtype: object

# %%
kiva_data['loan_themes_by_region'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15736 entries, 0 to 15735
# Data columns (total 21 columns):
# Partner ID            15736 non-null int64
# Field Partner Name    15736 non-null object
# sector                15736 non-null object
# Loan Theme ID         15736 non-null object
# Loan Theme Type       15736 non-null object
# country               15736 non-null object
# forkiva               15736 non-null object
# region                15736 non-null object
# geocode_old           1200 non-null object
# ISO                   15722 non-null object
# number                15736 non-null int64
# amount                15736 non-null int64
# LocationName          15736 non-null object
# geocode               13662 non-null object
# names                 13661 non-null object
# geo                   15736 non-null object
# lat                   13662 non-null float64
# lon                   13662 non-null float64
# mpi_region            15722 non-null object
# mpi_geo               9671 non-null object
# rural_pct             14344 non-null float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 2.5+ MB

# %%
kiva_data['loan_theme_ids'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779092 entries, 0 to 779091
# Data columns (total 4 columns):
# id                 779092 non-null int64
# Loan Theme ID      764279 non-null object
# Loan Theme Type    764279 non-null object
# Partner ID         764279 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.8+ MB

# %%
kiva_data['loan_themes_by_region']
# Out:
#        Partner ID                           Field Partner Name  \
# 0               9              KREDIT Microfinance Institution
# 1               9              KREDIT Microfinance Institution
# 2               9              KREDIT Microfinance Institution
# 3               9              KREDIT Microfinance Institution
# 4               9              KREDIT Microfinance Institution
# 5               9              KREDIT Microfinance Institution
# 6               9              KREDIT Microfinance Institution
# 7               9              KREDIT Microfinance Institution
# 8               9              KREDIT Microfinance Institution
# 9               9              KREDIT Microfinance Institution
# 10              9              KREDIT Microfinance Institution
# 11              9              KREDIT Microfinance Institution
# 12              9              KREDIT Microfinance Institution
# 13              9              KREDIT Microfinance Institution
# 14              9              KREDIT Microfinance Institution
# 15              9              KREDIT Microfinance Institution
# 16              9              KREDIT Microfinance Institution
# 17              9              KREDIT Microfinance Institution
# 18              9              KREDIT Microfinance Institution
# 19              9              KREDIT Microfinance Institution
# 20              9              KREDIT Microfinance Institution
# 21              9              KREDIT Microfinance Institution
# 22              9              KREDIT Microfinance Institution
# 23              9              KREDIT Microfinance Institution
# 24              9              KREDIT Microfinance Institution
# 25              9              KREDIT Microfinance Institution
# 26              9              KREDIT Microfinance Institution
# 27              9              KREDIT Microfinance Institution
# 28              9              KREDIT Microfinance Institution
# 29              9              KREDIT Microfinance Institution
# ...           ...                                          ...
# 15706         527                           FundaciÍ_n Sartawi
# 15707         527                           FundaciÍ_n Sartawi
# 15708         528                                    Inyenyeri
# 15709         529                           N/A, direct to LLK
# 15710         530                  N/A, direct to Jakana Foods
# 15711         531            N/A, direct to Azimuth Group Corp
# 15712         532             N/A, direct to All Across Africa
# 15713         533                                  MEC APROVAG
# 15714         533                                  MEC APROVAG
# 15715         533                                  MEC APROVAG
# 15716         534                  N/A, direct to ANA by Karma
# 15717         535  N/A, direct to Ab Ovo Confectionery Limited
# 15718         536                     N/A, direct to EcoEnergy
# 15719         538                                    iDE Ghana
# 15720         538                                    iDE Ghana
# 15721         538                                    iDE Ghana
# 15722         538                                    iDE Ghana
# 15723         538                                    iDE Ghana
# 15724         538                                    iDE Ghana
# 15725         538                                    iDE Ghana
# 15726         538                                    iDE Ghana
# 15727         538                                    iDE Ghana
# 15728         538                                    iDE Ghana
# 15729         538                                    iDE Ghana
# 15730         538                                    iDE Ghana
# 15731         539                       N/A, direct to Sevamob
# 15732         540                       N/A, direct to Sanergy
# 15733         542                   N/A direct to BioLite Inc.
# 15734         543                  N/A direct to LegWorks Inc.
# 15735         545                    N/A, direct to Solar Home
#
#                             sector    Loan Theme ID         Loan Theme Type  \
# 0      General Financial Inclusion  a1050000000slfi        Higher Education
# 1      General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 2      General Financial Inclusion  a1050000000slfi        Higher Education
# 3      General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 4      General Financial Inclusion  a1050000002X1Uu              Sanitation
# 5      General Financial Inclusion  a1050000000slfi        Higher Education
# 6      General Financial Inclusion  a1050000007VvXr      Solar Home Systems
# 7      General Financial Inclusion  a1050000000weyk                 General
# 8      General Financial Inclusion  a1050000007VvXr      Solar Home Systems
# 9      General Financial Inclusion  a1050000000slfi        Higher Education
# 10     General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 11     General Financial Inclusion  a1050000002X1Uu              Sanitation
# 12     General Financial Inclusion  a1050000002X1Uu              Sanitation
# 13     General Financial Inclusion  a1050000000slfi        Higher Education
# 14     General Financial Inclusion  a1050000000weyk                 General
# 15     General Financial Inclusion  a1050000000slfi        Higher Education
# 16     General Financial Inclusion  a1050000000weyk                 General
# 17     General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 18     General Financial Inclusion  a1050000000slfi        Higher Education
# 19     General Financial Inclusion  a1050000000slfi        Higher Education
# 20     General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 21     General Financial Inclusion  a1050000000slfi        Higher Education
# 22     General Financial Inclusion  a1050000000weyk                 General
# 23     General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# 24     General Financial Inclusion  a1050000007VvXr      Solar Home Systems
# 25     General Financial Inclusion  a1050000000slfi        Higher Education
# 26     General Financial Inclusion  a1050000007VvXr      Solar Home Systems
# 27     General Financial Inclusion  a1050000000weyk                 General
# 28     General Financial Inclusion  a1050000000slfi        Higher Education
# 29     General Financial Inclusion  a10500000068jPe  Vulnerable Populations
# ...                            ...              ...                     ...
# 15706  General Financial Inclusion  a1050000007zQAc             Agriculture
# 15707  General Financial Inclusion  a1050000007zQAc             Agriculture
# 15708                 Clean Energy  a10500000075MYG         Clean Cookstove
# 15709                   DSE Direct  a1050000008OYiQ                     SME
# 15710                   DSE Direct  a1050000008OYpb                     SME
# 15711                   DSE Direct  a1050000008OYxu      Solar Home Systems
# 15712                   DSE Direct  a1050000008Oui7                     SME
# 15713                  Agriculture  a1050000008HMXp             Agriculture
# 15714                  Agriculture  a1050000008HMXp             Agriculture
# 15715                  Agriculture  a1050000008HMXp             Agriculture
# 15716                   DSE Direct  a1050000007qa7g                 Artisan
# 15717                   DSE Direct  a1050000007yx24                     SME
# 15718                   DSE Direct  a1050000007yxE9      Solar Home Systems
# 15719         Water and Sanitation  a10500000080haV              Sanitation
# 15720         Water and Sanitation  a10500000080haV              Sanitation
# 15721         Water and Sanitation  a10500000080haV              Sanitation
# 15722         Water and Sanitation  a10500000080haV              Sanitation
# 15723         Water and Sanitation  a10500000080haV              Sanitation
# 15724         Water and Sanitation  a10500000080haV              Sanitation
# 15725         Water and Sanitation  a10500000080haV              Sanitation
# 15726         Water and Sanitation  a10500000080haV              Sanitation
# 15727         Water and Sanitation  a10500000080haV              Sanitation
# 15728         Water and Sanitation  a10500000080haV              Sanitation
# 15729         Water and Sanitation  a10500000080haV              Sanitation
# 15730         Water and Sanitation  a10500000080haV              Sanitation
# 15731                   DSE Direct  a10500000081IYl                  Health
# 15732                   DSE Direct  a10500000081HIw    Water and Sanitation
# 15733                   DSE Direct  a1050000008AQrj         Clean Cookstove
# 15734                   DSE Direct  a1050000008AQwt                  Health
# 15735                   DSE Direct  a1050000008ASxg      Solar Home Systems
#
#                country forkiva                    region  \
# 0             Cambodia      No          Banteay Meanchey
# 1             Cambodia      No       Battambang Province
# 2             Cambodia      No       Battambang Province
# 3             Cambodia      No     Kampong Cham Province
# 4             Cambodia      No     Kampong Cham Province
# 5             Cambodia      No     Kampong Cham Province
# 6             Cambodia      No     Kampong Cham Province
# 7             Cambodia      No  Kampong Chhnang Province
# 8             Cambodia      No  Kampong Chhnang Province
# 9             Cambodia      No  Kampong Chhnang Province
# 10            Cambodia      No  Kampong Chhnang Province
# 11            Cambodia      No  Kampong Chhnang Province
# 12            Cambodia      No     Kampong Speu Province
# 13            Cambodia      No     Kampong Speu Province
# 14            Cambodia      No     Kampong Speu Province
# 15            Cambodia      No           Kampot Province
# 16            Cambodia      No           Kandal Province
# 17            Cambodia      No           Kandal Province
# 18            Cambodia      No           Kandal Province
# 19            Cambodia      No           Kratie Province
# 20            Cambodia      No           Kratie Province
# 21            Cambodia      No                Phnom Penh
# 22            Cambodia      No        Prey Veng Province
# 23            Cambodia      No        Prey Veng Province
# 24            Cambodia      No        Prey Veng Province
# 25            Cambodia      No        Prey Veng Province
# 26            Cambodia      No           Pursat Province
# 27            Cambodia      No           Pursat Province
# 28            Cambodia      No           Pursat Province
# 29            Cambodia      No           Pursat Province
# ...                ...     ...                       ...
# 15706          Bolivia      No                 YapacanÍ_
# 15707          Bolivia      No         cruce Villa Adela
# 15708           Rwanda      No                    Rubavu
# 15709            Kenya      No                    Kiambu
# 15710           Uganda      No                   Kampala
# 15711     Sierra Leone      No                  Freetown
# 15712           Uganda      No                   Kampala
# 15713          Senegal      No               Netteboulou
# 15714          Senegal      No                    Nguene
# 15715          Senegal      No                  Sankagne
# 15716           Bhutan      No                   Thimphu
# 15717            Ghana      No                     Accra
# 15718         Pakistan      No                   Karachi
# 15719            Ghana      No                     Agric
# 15720            Ghana      No                     Dungu
# 15721            Ghana      No                      Gumo
# 15722            Ghana      No               Jisonaayili
# 15723            Ghana      No                    Karaga
# 15724            Ghana      No                  Katariga
# 15725            Ghana      No                  Kumbungu
# 15726            Ghana      No                    Kuokuo
# 15727            Ghana      No                 Nakpanzoo
# 15728            Ghana      No                 Sagnarigu
# 15729            Ghana      No                      Taha
# 15730            Ghana      No                   Vitting
# 15731     South Africa      No                  Nkangala
# 15732            Kenya      No                   Nairobi
# 15733           Uganda      No                   Kampala
# 15734           Canada      No                   Toronto
# 15735  Myanmar (Burma)      No                    Yangon
#
#                     geocode_old  ISO    ...     amount  \
# 0                (13.75, 103.0)  KHM    ...        450
# 1                           NaN  KHM    ...      20275
# 2                           NaN  KHM    ...       9150
# 3                 (12.0, 105.5)  KHM    ...     604950
# 4                 (12.0, 105.5)  KHM    ...        275
# 5                 (12.0, 105.5)  KHM    ...      62225
# 6                 (12.0, 105.5)  KHM    ...       1300
# 7                 (12.0, 104.5)  KHM    ...     237175
# 8                 (12.0, 104.5)  KHM    ...       3050
# 9                 (12.0, 104.5)  KHM    ...      31425
# 10                (12.0, 104.5)  KHM    ...     323950
# 11                (12.0, 104.5)  KHM    ...       1000
# 12                          NaN  KHM    ...       1000
# 13                          NaN  KHM    ...      15625
# 14                          NaN  KHM    ...      20925
# 15                          NaN  KHM    ...      18650
# 16          (11.5, 104.8333333)  KHM    ...      17025
# 17          (11.5, 104.8333333)  KHM    ...      68075
# 18          (11.5, 104.8333333)  KHM    ...      63250
# 19                          NaN  KHM    ...      15650
# 20                          NaN  KHM    ...     303275
# 21         (11.55, 104.9166667)  KHM    ...      39275
# 22                (11.5, 105.5)  KHM    ...        200
# 23                (11.5, 105.5)  KHM    ...     542350
# 24                (11.5, 105.5)  KHM    ...       4500
# 25                (11.5, 105.5)  KHM    ...     109050
# 26                          NaN  KHM    ...        450
# 27                          NaN  KHM    ...       1500
# 28                          NaN  KHM    ...       8600
# 29                          NaN  KHM    ...       1850
# ...                         ...  ...    ...        ...
# 15706                       NaN  BOL    ...       2625
# 15707                       NaN  BOL    ...        800
# 15708                       NaN  RWA    ...       9275
# 15709  (-1.1666667, 36.8333333)  KEN    ...      36000
# 15710   (0.3155556, 32.5655556)  UGA    ...      30000
# 15711                       NaN  SLE    ...      30000
# 15712   (0.3155556, 32.5655556)  UGA    ...      50000
# 15713                       NaN  SEN    ...       1725
# 15714                       NaN  SEN    ...      15625
# 15715                       NaN  SEN    ...      25225
# 15716                       NaN  BTN    ...      20000
# 15717        (5.55, -0.2166667)  GHA    ...      25000
# 15718                       NaN  PAK    ...      50000
# 15719                       NaN  GHA    ...        475
# 15720                       NaN  GHA    ...        150
# 15721                       NaN  GHA    ...        475
# 15722                       NaN  GHA    ...        475
# 15723                       NaN  GHA    ...        775
# 15724                       NaN  GHA    ...        600
# 15725                       NaN  GHA    ...        950
# 15726                       NaN  GHA    ...        575
# 15727                       NaN  GHA    ...        150
# 15728                       NaN  GHA    ...        150
# 15729                       NaN  GHA    ...        475
# 15730                       NaN  GHA    ...       1100
# 15731                       NaN  ZAF    ...      50000
# 15732  (-1.2833333, 36.8166667)  KEN    ...      50000
# 15733   (0.3155556, 32.5655556)  UGA    ...      50000
# 15734                       NaN  CAN    ...      50000
# 15735                       NaN  MMR    ...      50000
#
#                              LocationName  \
# 0              Banteay Meanchey, Cambodia
# 1           Battambang Province, Cambodia
# 2           Battambang Province, Cambodia
# 3         Kampong Cham Province, Cambodia
# 4         Kampong Cham Province, Cambodia
# 5         Kampong Cham Province, Cambodia
# 6         Kampong Cham Province, Cambodia
# 7      Kampong Chhnang Province, Cambodia
# 8      Kampong Chhnang Province, Cambodia
# 9      Kampong Chhnang Province, Cambodia
# 10     Kampong Chhnang Province, Cambodia
# 11     Kampong Chhnang Province, Cambodia
# 12        Kampong Speu Province, Cambodia
# 13        Kampong Speu Province, Cambodia
# 14        Kampong Speu Province, Cambodia
# 15              Kampot Province, Cambodia
# 16              Kandal Province, Cambodia
# 17              Kandal Province, Cambodia
# 18              Kandal Province, Cambodia
# 19              Kratie Province, Cambodia
# 20              Kratie Province, Cambodia
# 21                   Phnom Penh, Cambodia
# 22           Prey Veng Province, Cambodia
# 23           Prey Veng Province, Cambodia
# 24           Prey Veng Province, Cambodia
# 25           Prey Veng Province, Cambodia
# 26              Pursat Province, Cambodia
# 27              Pursat Province, Cambodia
# 28              Pursat Province, Cambodia
# 29              Pursat Province, Cambodia
# ...                                   ...
# 15706                  YapacanÍ_, Bolivia
# 15707          cruce Villa Adela, Bolivia
# 15708                      Rubavu, Rwanda
# 15709                       Kiambu, Kenya
# 15710                     Kampala, Uganda
# 15711              Freetown, Sierra Leone
# 15712                     Kampala, Uganda
# 15713                Netteboulou, Senegal
# 15714                     Nguene, Senegal
# 15715                   Sankagne, Senegal
# 15716                     Thimphu, Bhutan
# 15717                        Accra, Ghana
# 15718                   Karachi, Pakistan
# 15719                        Agric, Ghana
# 15720                        Dungu, Ghana
# 15721                         Gumo, Ghana
# 15722                  Jisonaayili, Ghana
# 15723                       Karaga, Ghana
# 15724                     Katariga, Ghana
# 15725                     Kumbungu, Ghana
# 15726                       Kuokuo, Ghana
# 15727                    Nakpanzoo, Ghana
# 15728                    Sagnarigu, Ghana
# 15729                         Taha, Ghana
# 15730                      Vitting, Ghana
# 15731              Nkangala, South Africa
# 15732                      Nairobi, Kenya
# 15733                     Kampala, Uganda
# 15734                     Toronto, Canada
# 15735             Yangon, Myanmar (Burma)
#
#                                           geocode  \
# 0                     [(13.6672596, 102.8975098)]
# 1                      [(13.0286971, 102.989615)]
# 2                      [(13.0286971, 102.989615)]
# 3                     [(12.0982918, 105.3131185)]
# 4                     [(12.0982918, 105.3131185)]
# 5                     [(12.0982918, 105.3131185)]
# 6                     [(12.0982918, 105.3131185)]
# 7                     [(12.1392352, 104.5655273)]
# 8                     [(12.1392352, 104.5655273)]
# 9                     [(12.1392352, 104.5655273)]
# 10                    [(12.1392352, 104.5655273)]
# 11                    [(12.1392352, 104.5655273)]
# 12                    [(11.6155109, 104.3791912)]
# 13                    [(11.6155109, 104.3791912)]
# 14                    [(11.6155109, 104.3791912)]
# 15                    [(10.7412089, 104.1930918)]
# 16                    [(11.2237383, 105.1258955)]
# 17                    [(11.2237383, 105.1258955)]
# 18                    [(11.2237383, 105.1258955)]
# 19                    [(12.8606299, 105.9699878)]
# 20                    [(12.8606299, 105.9699878)]
# 21                    [(11.5448729, 104.8921668)]
# 22                    [(11.3802442, 105.5005483)]
# 23                    [(11.3802442, 105.5005483)]
# 24                    [(11.3802442, 105.5005483)]
# 25                    [(11.3802442, 105.5005483)]
# 26                    [(12.3663211, 103.6362715)]
# 27                    [(12.3663211, 103.6362715)]
# 28                    [(12.3663211, 103.6362715)]
# 29                    [(12.3663211, 103.6362715)]
# ...                                           ...
# 15706         [(-17.4013758, -63.88178319999999)]
# 15707                [(-16.5343037, -68.1903483)]
# 15708                  [(-1.6986475, 29.3714909)]
# 15709                  [(-1.1748105, 36.8304102)]
# 15710                   [(0.3475964, 32.5825197)]
# 15711                  [(8.4656765, -13.2317225)]
# 15712                   [(0.3475964, 32.5825197)]
# 15713                                         NaN
# 15714                   [(15.481636, -16.104843)]
# 15715                                         NaN
# 15716                  [(27.4727924, 89.6392863)]
# 15717                   [(5.6037168, -0.1869644)]
# 15718                  [(24.8614622, 67.0099388)]
# 15719                    [(6.9357571, -1.675158)]
# 15720  [(9.374548899999999, -0.8794310999999999)]
# 15721                                         NaN
# 15722                                         NaN
# 15723           [(9.926672199999999, -0.4337304)]
# 15724                                         NaN
# 15725          [(9.5604984, -0.9486222999999999)]
# 15726                   [(9.5237374, -0.9181876)]
# 15727                                         NaN
# 15728             [(9.4139, -0.8669323999999999)]
# 15729                   [(9.4358436, -0.7841872)]
# 15730                      [(9.4220024, -0.8439)]
# 15731                 [(-25.9459898, 29.6035495)]
# 15732                  [(-1.2920659, 36.8219462)]
# 15733                   [(0.3475964, 32.5825197)]
# 15734                  [(43.653226, -79.3831843)]
# 15735           [(16.8660694, 96.19513200000002)]
#
#                                                    names  \
# 0                    Banteay Meanchey Province; Cambodia
# 1                          Battambang Province; Cambodia
# 2                          Battambang Province; Cambodia
# 3                        Kampong Cham Province; Cambodia
# 4                        Kampong Cham Province; Cambodia
# 5                        Kampong Cham Province; Cambodia
# 6                        Kampong Cham Province; Cambodia
# 7                     Kampong Chhnang Province; Cambodia
# 8                     Kampong Chhnang Province; Cambodia
# 9                     Kampong Chhnang Province; Cambodia
# 10                    Kampong Chhnang Province; Cambodia
# 11                    Kampong Chhnang Province; Cambodia
# 12                       Kampong Speu Province; Cambodia
# 13                       Kampong Speu Province; Cambodia
# 14                       Kampong Speu Province; Cambodia
# 15                             Kampot Province; Cambodia
# 16                                      Kandal; Cambodia
# 17                                      Kandal; Cambodia
# 18                                      Kandal; Cambodia
# 19                            KratiÍ© Province; Cambodia
# 20                            KratiÍ© Province; Cambodia
# 21                      Phnom Penh; Phnom Penh; Cambodia
# 22                          Prey Veng Province; Cambodia
# 23                          Prey Veng Province; Cambodia
# 24                          Prey Veng Province; Cambodia
# 25                          Prey Veng Province; Cambodia
# 26                             Pursat Province; Cambodia
# 27                             Pursat Province; Cambodia
# 28                             Pursat Province; Cambodia
# 29                             Pursat Province; Cambodia
# ...                                                  ...
# 15706   Yapacani; Ichilo; Santa Cruz Department; Bolivia
# 15707  Cruce Villa Adela; El Alto; Departamento de La...
# 15708                   Rubavu; Western Province; Rwanda
# 15709                       Kiambu; Kiambu County; Kenya
# 15710           Kampala; Kampala; Central Region; Uganda
# 15711  Freetown; Western Area Urban; Western Area; Si...
# 15712           Kampala; Kampala; Central Region; Uganda
# 15713                                                NaN
# 15714                      Nguene; Louga; Louga; Senegal
# 15715                                                NaN
# 15716                           Thimphu; Thimphu; Bhutan
# 15717  Accra; Accra Metropolis; Greater Accra Region;...
# 15718         Karachi; Karachi District; Sindh; Pakistan
# 15719  Agric; Ofinso; Afigya-Sekyere; Ashanti Region;...
# 15720  Dungu; Tamale; Tamale Municipal; Northern Regi...
# 15721                                                NaN
# 15722                                                NaN
# 15723             Karaga; Karaga; Northern Region; Ghana
# 15724                                                NaN
# 15725            Kumbungu; Tolon; Northern Region; Ghana
# 15726               Kukuo; Tolon; Northern Region; Ghana
# 15727                                                NaN
# 15728  Sagnarigu Road; Tamale; Tamale Municipal; Nort...
# 15729     Taha; Tamale Municipal; Northern Region; Ghana
# 15730  Vitting Road; Tamale; Tamale Municipal; Northe...
# 15731                 Nkangala; Mpumalanga; South Africa
# 15732                     Nairobi; Nairobi County; Kenya
# 15733           Kampala; Kampala; Central Region; Uganda
# 15734         Toronto; Toronto Division; Ontario; Canada
# 15735             Yangon; Yangon Region; Myanmar (Burma)
#
#                                             geo        lat         lon  \
# 0                     (13.6672596, 102.8975098)  13.667260  102.897510
# 1                      (13.0286971, 102.989615)  13.028697  102.989615
# 2                      (13.0286971, 102.989615)  13.028697  102.989615
# 3                     (12.0982918, 105.3131185)  12.098292  105.313119
# 4                     (12.0982918, 105.3131185)  12.098292  105.313119
# 5                     (12.0982918, 105.3131185)  12.098292  105.313119
# 6                     (12.0982918, 105.3131185)  12.098292  105.313119
# 7                     (12.1392352, 104.5655273)  12.139235  104.565527
# 8                     (12.1392352, 104.5655273)  12.139235  104.565527
# 9                     (12.1392352, 104.5655273)  12.139235  104.565527
# 10                    (12.1392352, 104.5655273)  12.139235  104.565527
# 11                    (12.1392352, 104.5655273)  12.139235  104.565527
# 12                    (11.6155109, 104.3791912)  11.615511  104.379191
# 13                    (11.6155109, 104.3791912)  11.615511  104.379191
# 14                    (11.6155109, 104.3791912)  11.615511  104.379191
# 15                    (10.7412089, 104.1930918)  10.741209  104.193092
# 16                    (11.2237383, 105.1258955)  11.223738  105.125896
# 17                    (11.2237383, 105.1258955)  11.223738  105.125896
# 18                    (11.2237383, 105.1258955)  11.223738  105.125896
# 19                    (12.8606299, 105.9699878)  12.860630  105.969988
# 20                    (12.8606299, 105.9699878)  12.860630  105.969988
# 21                    (11.5448729, 104.8921668)  11.544873  104.892167
# 22                    (11.3802442, 105.5005483)  11.380244  105.500548
# 23                    (11.3802442, 105.5005483)  11.380244  105.500548
# 24                    (11.3802442, 105.5005483)  11.380244  105.500548
# 25                    (11.3802442, 105.5005483)  11.380244  105.500548
# 26                    (12.3663211, 103.6362715)  12.366321  103.636271
# 27                    (12.3663211, 103.6362715)  12.366321  103.636271
# 28                    (12.3663211, 103.6362715)  12.366321  103.636271
# 29                    (12.3663211, 103.6362715)  12.366321  103.636271
# ...                                         ...        ...         ...
# 15706         (-17.4013758, -63.88178319999999) -17.401376  -63.881783
# 15707                (-16.5343037, -68.1903483) -16.534304  -68.190348
# 15708                  (-1.6986475, 29.3714909)  -1.698647   29.371491
# 15709                  (-1.1748105, 36.8304102)  -1.174810   36.830410
# 15710                   (0.3475964, 32.5825197)   0.347596   32.582520
# 15711                  (8.4656765, -13.2317225)   8.465677  -13.231723
# 15712                   (0.3475964, 32.5825197)   0.347596   32.582520
# 15713                          (1000.0, 1000.0)        NaN         NaN
# 15714                   (15.481636, -16.104843)  15.481636  -16.104843
# 15715                          (1000.0, 1000.0)        NaN         NaN
# 15716                  (27.4727924, 89.6392863)  27.472792   89.639286
# 15717                   (5.6037168, -0.1869644)   5.603717   -0.186964
# 15718                  (24.8614622, 67.0099388)  24.861462   67.009939
# 15719                    (6.9357571, -1.675158)   6.935757   -1.675158
# 15720  (9.374548899999999, -0.8794310999999999)   9.374549   -0.879431
# 15721                          (1000.0, 1000.0)        NaN         NaN
# 15722                          (1000.0, 1000.0)        NaN         NaN
# 15723           (9.926672199999999, -0.4337304)   9.926672   -0.433730
# 15724                          (1000.0, 1000.0)        NaN         NaN
# 15725          (9.5604984, -0.9486222999999999)   9.560498   -0.948622
# 15726                   (9.5237374, -0.9181876)   9.523737   -0.918188
# 15727                          (1000.0, 1000.0)        NaN         NaN
# 15728             (9.4139, -0.8669323999999999)   9.413900   -0.866932
# 15729                   (9.4358436, -0.7841872)   9.435844   -0.784187
# 15730                      (9.4220024, -0.8439)   9.422002   -0.843900
# 15731                 (-25.9459898, 29.6035495) -25.945990   29.603549
# 15732                  (-1.2920659, 36.8219462)  -1.292066   36.821946
# 15733                   (0.3475964, 32.5825197)   0.347596   32.582520
# 15734                  (43.653226, -79.3831843)  43.653226  -79.383184
# 15735           (16.8660694, 96.19513200000002)  16.866069   96.195132
#
#                                         mpi_region  \
# 0                      Banteay Mean Chey, Cambodia
# 1                      Banteay Mean Chey, Cambodia
# 2                      Banteay Mean Chey, Cambodia
# 3                           Kampong Cham, Cambodia
# 4                           Kampong Cham, Cambodia
# 5                           Kampong Cham, Cambodia
# 6                           Kampong Cham, Cambodia
# 7                        Kampong Chhnang, Cambodia
# 8                        Kampong Chhnang, Cambodia
# 9                        Kampong Chhnang, Cambodia
# 10                       Kampong Chhnang, Cambodia
# 11                       Kampong Chhnang, Cambodia
# 12                            Phnom Penh, Cambodia
# 13                            Phnom Penh, Cambodia
# 14                            Phnom Penh, Cambodia
# 15                          Kampot & Kep, Cambodia
# 16                                Kandal, Cambodia
# 17                                Kandal, Cambodia
# 18                                Kandal, Cambodia
# 19                                Kratie, Cambodia
# 20                                Kratie, Cambodia
# 21                            Phnom Penh, Cambodia
# 22                             Prey Veng, Cambodia
# 23                             Prey Veng, Cambodia
# 24                             Prey Veng, Cambodia
# 25                             Prey Veng, Cambodia
# 26                                Pursat, Cambodia
# 27                                Pursat, Cambodia
# 28                                Pursat, Cambodia
# 29                                Pursat, Cambodia
# ...                                            ...
# 15706  Santa Cruz, Bolivia, Plurinational State of
# 15707      La Paz, Bolivia, Plurinational State of
# 15708                                North, Rwanda
# 15709                                Nyanza, Kenya
# 15710                              Kampala, Uganda
# 15711                  Western Rural, Sierra Leone
# 15712                              Kampala, Uganda
# 15713                                          SEN
# 15714                              Center, Senegal
# 15715                                          SEN
# 15716                              Thimphu, Bhutan
# 15717                         Greater Accra, Ghana
# 15718                              Sindh, Pakistan
# 15719                               Ashanti, Ghana
# 15720                              Northern, Ghana
# 15721                                          GHA
# 15722                                          GHA
# 15723                              Northern, Ghana
# 15724                                          GHA
# 15725                              Northern, Ghana
# 15726                              Northern, Ghana
# 15727                                          GHA
# 15728                              Northern, Ghana
# 15729                              Northern, Ghana
# 15730                              Northern, Ghana
# 15731                                          ZAF
# 15732                               Nairobi, Kenya
# 15733                              Kampala, Uganda
# 15734                                          CAN
# 15735                              Yangon, Myanmar
#
#                                 mpi_geo rural_pct
# 0             (13.6672596, 102.8975098)      90.0
# 1             (13.6672596, 102.8975098)      90.0
# 2             (13.6672596, 102.8975098)      90.0
# 3             (11.9924294, 105.4645408)      90.0
# 4             (11.9924294, 105.4645408)      90.0
# 5             (11.9924294, 105.4645408)      90.0
# 6             (11.9924294, 105.4645408)      90.0
# 7             (12.1392352, 104.5655273)      90.0
# 8             (12.1392352, 104.5655273)      90.0
# 9             (12.1392352, 104.5655273)      90.0
# 10            (12.1392352, 104.5655273)      90.0
# 11            (12.1392352, 104.5655273)      90.0
# 12            (11.5448729, 104.8921668)      90.0
# 13            (11.5448729, 104.8921668)      90.0
# 14            (11.5448729, 104.8921668)      90.0
# 15            (10.4790637, 104.2941991)      90.0
# 16            (11.2237383, 105.1258955)      90.0
# 17            (11.2237383, 105.1258955)      90.0
# 18            (11.2237383, 105.1258955)      90.0
# 19            (12.4896877, 106.0287512)      90.0
# 20            (12.4896877, 106.0287512)      90.0
# 21            (11.5448729, 104.8921668)      90.0
# 22            (11.3802442, 105.5005483)      90.0
# 23            (11.3802442, 105.5005483)      90.0
# 24            (11.3802442, 105.5005483)      90.0
# 25            (11.3802442, 105.5005483)      90.0
# 26            (12.3663211, 103.6362715)      90.0
# 27            (12.3663211, 103.6362715)      90.0
# 28            (12.3663211, 103.6362715)      90.0
# 29            (12.3663211, 103.6362715)      90.0
# ...                                 ...       ...
# 15706        (-17.8145819, -63.1560853)      77.0
# 15707  (-16.489689, -68.11929359999999)      77.0
# 15708          (-1.5009963, 29.6384954)       NaN
# 15709          (-1.2849963, 36.8272273)       NaN
# 15710           (0.3475964, 32.5825197)       NaN
# 15711           (8.3114983, -13.035694)       NaN
# 15712           (0.3475964, 32.5825197)       NaN
# 15713                               NaN      80.0
# 15714            (14.72001, -17.465533)      80.0
# 15715                               NaN      80.0
# 15716          (27.4727924, 89.6392863)       NaN
# 15717            (5.8142836, 0.0746767)       NaN
# 15718   (25.8943018, 68.52471489999999)       NaN
# 15719           (6.7470436, -1.5208624)       NaN
# 15720   (9.543926899999999, -0.9056623)       NaN
# 15721                               NaN       NaN
# 15722                               NaN       NaN
# 15723   (9.543926899999999, -0.9056623)       NaN
# 15724                               NaN       NaN
# 15725   (9.543926899999999, -0.9056623)       NaN
# 15726   (9.543926899999999, -0.9056623)       NaN
# 15727                               NaN       NaN
# 15728   (9.543926899999999, -0.9056623)       NaN
# 15729   (9.543926899999999, -0.9056623)       NaN
# 15730   (9.543926899999999, -0.9056623)       NaN
# 15731                               NaN       NaN
# 15732          (-1.2920659, 36.8219462)       NaN
# 15733           (0.3475964, 32.5825197)       NaN
# 15734                               NaN       NaN
# 15735   (16.8660694, 96.19513200000002)       NaN
#
# [15736 rows x 21 columns]
